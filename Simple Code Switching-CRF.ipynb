# %%
import pysubs2
import spacy
import pandas as pd
import numpy as np
import os.path
import pycrfsuite

from collections import Counter

from spacy.tokens import Doc # to create empty Doc
from spacy.vocab import Vocab # to create empty Vocab

from sklearn.metrics import accuracy_score, f1_score, classification_report, recall_score, precision_score
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import MultiLabelBinarizer

# %%
nlp_en = spacy.load('en')
nlp_fr = spacy.load('fr')

# %%
def load_data():
    if os.path.exists('bcbc_fr_parsed') and \
        os.path.exists('bcbc_en_parsed.bin'):
        return Doc(Vocab()).from_disk('bcbc_fr_parsed.bin'), \
                    Doc(Vocab()).from_disk('bcbc_en_parsed.bin')
    else:  
        subs_french = pysubs2.load('bon_french/Bon.Cop.Bad.Cop.2006.720p.BluRay.H264.AAC-RARBG.srt',
                            encoding='iso-8859-1')
        subs_eng = pysubs2.load('bon_eng/Bon.Cop.Bad.Cop.2006.720p.BluRay.x264-.YTS.AG.srt')
        french_subs = " ".join(line.text for line in subs_french)
        french_parsed = nlp_fr(french_subs)

        eng_subs = " ".join(line.text for line in subs_eng)
        eng_parsed = nlp_en(eng_subs)

        french_parsed.to_disk('bcbc_fr_parsed.bin')
        eng_parsed.to_disk('bcbc_en_parsed.bin')

        return french_subs, french_parsed, eng_subs, eng_parsed

# %%
french_subs, french_parsed, eng_subs, eng_parsed = load_data()

# %%
[x.tag_ for x in french_parsed]
# TODO: Get tokens from each script and align them somehow
#       Maybe they don't have to be aligned, just use indexing to get
#       "corresponding" token from other script
#       Keep track of current script and switch according to prob_matrix 
#       below, choose one monolingual script for starters
# Out:
# ['PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'ADV___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PRON__PronType=Rel',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Number=Sing',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'DET__Gender=Masc|Number=Sing',
#  'ADV___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'DET__Number=Sing|Poss=Yes',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'DET__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'DET__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'NOUN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PRON__PronType=Rel',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'PRON__Number=Plur|Person=2',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'SCONJ___',
#  'ADV___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'VERB__Gender=Fem|Number=Plur|Tense=Past|VerbForm=Part',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADJ__Number=Plur',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'PROPN__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Tense=Past|VerbForm=Part',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Fem|Number=Plur',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'AUX__VerbForm=Inf',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__PronType=Rel',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'SCONJ___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'PRON__Number=Sing|PronType=Rel',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'VERB__VerbForm=Inf',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'SCONJ___',
#  'NOUN__Gender=Masc',
#  'ADV___',
#  'VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'NOUN___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV',
#  'VERB',
#  'PRON__Number=Sing|Person=3',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PROPN___',
#  'PROPN___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADJ__Number=Sing',
#  'ADJ___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'ADP___',
#  'PROPN___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Number=Plur',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Sing|PronType=Art',
#  'NOUN__Number=Sing',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Fem|Number=Sing',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN___',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin',
#  'ADV___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADV___',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Plur|Person=2',
#  'VERB__Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'VERB__Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'DET__Gender=Fem|Number=Sing|PronType=Dem',
#  'ADJ__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NUM__NumType=Card',
#  'PUNCT___',
#  'NUM__NumType=Card',
#  'ADP___',
#  'PROPN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Number=Sing|PronType=Rel',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Fem|Number=Sing|Poss=Yes',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Masc',
#  'ADV__Polarity=Neg',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PROPN___',
#  'X___',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADV___',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'ADJ__Gender=Fem|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'ADV__Polarity=Neg',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADP___',
#  'PROPN___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'CCONJ___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PRON__Number=Sing|Person=3',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Plur|Person=3',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Plur',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'ADV___',
#  'ADP___',
#  'VERB__VerbForm=Inf',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADJ__Gender=Masc',
#  'NOUN__Gender=Fem|Number=Plur',
#  'VERB__VerbForm=Inf',
#  'DET__Number=Sing',
#  'NOUN__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'ADP___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'CCONJ___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'ADP___',
#  'VERB__VerbForm=Inf',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'ADJ__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'VERB__VerbForm=Inf',
#  'ADJ__Gender=Fem|Number=Plur',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'ADV___',
#  'ADV___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADV__Polarity=Neg',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Number=Plur',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'NOUN__Gender=Masc',
#  'NOUN___',
#  'DET__Number=Sing|Poss=Yes',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PRON__Number=Sing|Person=1',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NOUN__Gender=Fem|Number=Sing',
#  'VERB__Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PUNCT___',
#  'NOUN___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'AUX__Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PRON__Number=Plur|Person=2',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADV___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Fem|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'SCONJ___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'ADV__Polarity=Neg',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADV___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADJ___',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADV___',
#  'NOUN__Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PUNCT___',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'DET__Gender=Fem|Number=Sing|Poss=Yes',
#  'ADJ__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PRON__PronType=Rel',
#  'PRON__Person=3|Reflex=Yes',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PRON__PronType=Rel',
#  'PRON__PronType=Rel',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing|NumType=Ord',
#  'ADJ__Gender=Fem|Number=Sing',
#  'SCONJ___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  ...]

# %%
bcbc_gs = pd.read_excel('BCBC_GS_annotator1.xlsx')

# %% [markdown]
#     eng frn
# eng
# frn

# %%
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'] != 'French/English']
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'] != "None"]
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'].notnull()]
bcbc_gs['Listened Language'].value_counts()
# Out:
# French     7650
# English    5803
# Name: Listened Language, dtype: int64

# %%
def prob_matrix(tokens, langs):
    """
    tokens: a pandas series containing all the tokens
    """
    
    switches = {lang: {}  for lang in langs}
    counts = Counter(zip(tokens, tokens[1:]))

    for (x, y), c in counts.items():
        switches[x][y] = c / float(len(tokens) - 1)
        
    return switches

# %%
prob = prob_matrix(bcbc_gs['Listened Language'], \
                             set(bcbc_gs['Listened Language']))
prob
# Out:
# {'French': {'French': 0.5489146595301814, 'English': 0.01977401129943503},
#  'English': {'French': 0.019699672911091287, 'English': 0.4116116562592923}}

# %%
fr_subs = french_subs.split(" ")
en_subs = eng_subs.split(" ")
len(en_subs), len(fr_subs)
# Out:
# (9589, 10225)

# %%
def lang_switcher(corpora, langs, start_lang):
    last_lang = start_lang
    last_index = langs.index(start_lang)
    cs_script = cs_script = corpora[last_lang][0] + " "
    
    for index, word in enumerate(en_subs):
        r = np.random.uniform(low=0.0, high=1.0)
        last_lang = langs[last_index]
    
        # Check if we switch
        if r > prob[last_lang][last_lang]:
            # Switch and get next word from other corpus
            last_index = last_index ^ 1
            last_lang = langs[last_index]
        
        cs_script += corpora[last_lang][index] + " "

    return cs_script

# %%
corpora = {"English": en_subs, "French": fr_subs}
langs = ["English", "French"]

eng_cs = lang_switcher(corpora, langs, "English")
fr_cs = lang_switcher(corpora, langs, "French")

# TODO: Pretty print these to remove all the slashes since it looks terrible
#       Maybe separate into sentences?
#       Try/catch block for last line since corpora are different lengths
#       Find itertools function or something instead of using XOR for index

# %%
targets = []

for lang in bcbc_gs["Listened Language"]:
    if lang == "French":
        targets.append(0)
    elif lang == "English":
        targets.append(1)
    else:
        targets.append(0)

# %%
sentences = []
targets = []

sent = []
sent_targets = []

for lang, token in zip(bcbc_gs["Listened Language"], bcbc_gs["Token"]):
    sent.append(token)
    
    if lang == "French":
        sent_targets.append(0)
    elif lang == "English":
        sent_targets.append(1)
    else:
        sent_targets.append(0)
        
    if token in (".", "?", "!"):
        sentences.append(sent)
        targets.append(sent_targets)
        sent = []
        sent_targets = []

# %%
import pycrfsuite

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'word.isupper=%s' % word.isupper(),
        'word.istitle=%s' % word.istitle(),
        'word.isdigit=%s' % word.isdigit(),
        'postag=' + postag,
        'postag[:2]=' + postag[:2],
    ]
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:word.istitle=%s' % word1.istitle(),
            '-1:word.isupper=%s' % word1.isupper(),
            '-1:postag=' + postag1,
            '-1:postag[:2]=' + postag1[:2],
        ])
    else:
        features.append('BOS')
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:word.istitle=%s' % word1.istitle(),
            '+1:word.isupper=%s' % word1.isupper(),
            '+1:postag=' + postag1,
            '+1:postag[:2]=' + postag1[:2],
        ])
    else:
        features.append('EOS')
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
text = " ".join([str(tok) for tok in bcbc_gs["Token"]])

# %%
mapped_targets = [{w: t for w, t in zip(sentence, target)} for sentence, target in zip(sentences, targets)]

# %% [markdown]
# ## Create inputs and outputs
# - Get the pos tag for each word and make sure that each word has a target
# - This might not be the best way of handling this
# - The current

# %%
y = []
x = []

for text, targets in zip(sentences, mapped_targets):
    _y = []
    sentence = []
    
    for word in nlp_fr(" ".join(list(map(lambda w: str(w), text)))):
        sentence.append((word.text, word.pos_))
        
        if word.text in targets:
            _y.append(targets[word.text])
        else:
            _y.append(0)        
    x.append(sentence)
    y.append(_y)

# %%
X = [sent2features(sent) for sent in x]
y = list(map(lambda _y: list(map(lambda x: str(x), _y)), y))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
kf = KFold(n_splits=5)

for i, (train_index, test_index) in enumerate(kf.split(X)):
    print("Fold : {} ".format(i + 1))
    X = np.array(X)
    y = np.array(y)
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = X[train_index], y[test_index]
    X_train = [X[i] for i in train_index]
    y_train = [y[i] for i in train_index]

    X_test = [X[i] for i in test_index]

    y_test = [y[i] for i in test_index]


    trainer = pycrfsuite.Trainer(verbose=False)

    for xseq, yseq in zip(X_train, y_train):
        trainer.append(xseq, yseq)
        
    trainer.set_params({
        'c1': 1.0,   # coefficient for L1 penalty
        'c2': 1e-3,  # coefficient for L2 penalty
        'max_iterations': 50,  # stop earlier

        # include transitions that are possible, but not observed
        'feature.possible_transitions': True
    })
    
    # %%time
    trainer.train('bon_cop_bad_cop.crfsuite')
    
    tagger = pycrfsuite.Tagger()
    tagger.open('bon_cop_bad_cop.crfsuite')
    
    # %%time
    y_pred = [tagger.tag(xseq) for xseq in X_test]
    
    y_test_flat = list(map(lambda x: int(x), itertools.chain.from_iterable(y_test)))
    y_pred_flat = list(map(lambda x: int(x), itertools.chain.from_iterable(y_pred)))
    
    print(classification_report(y_test_flat, y_pred_flat))
    print(f1_score(y_test_flat, y_pred_flat))
    print(recall_score(y_test_flat, y_pred_flat))
    print(precision_score(y_test_flat, y_pred_flat))
# Out:
# Fold : 1
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 7.15 µs
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.72 µs
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      2473
#           1       0.95      0.91      0.93       800
#
# avg / total       0.97      0.97      0.97      3273
#
# 0.9302623160588612
# 0.90875
# 0.9528178243774574
# Fold : 2
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 12.2 µs
#              precision    recall  f1-score   support
#
#           0       0.99      0.98      0.98      2674
#           1       0.85      0.92      0.88       358
#
# avg / total       0.97      0.97      0.97      3032
#
# 0.8844086021505375
# 0.9189944134078212
# 0.8523316062176166
# Fold : 3
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.01 µs
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 8.82 µs
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      1687
#           1       0.95      0.90      0.93       579
#
# avg / total       0.96      0.96      0.96      2266
#
# 0.9252669039145909
# 0.8981001727115717
# 0.9541284403669725
# Fold : 4
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.34 µs
#              precision    recall  f1-score   support
#
#           0       0.88      0.97      0.92      1310
#           1       0.98      0.92      0.95      2055
#
# avg / total       0.94      0.94      0.94      3365
#
# 0.9468138484696438
# 0.9182481751824818
# 0.9772138788192646
# Fold : 5
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
# CPU times: user 5 µs, sys: 1e+03 ns, total: 6 µs
# Wall time: 11.9 µs
#              precision    recall  f1-score   support
#
#           0       0.97      0.95      0.96      1696
#           1       0.91      0.93      0.92       825
#
# avg / total       0.95      0.95      0.95      2521
#
# 0.9200477326968973
# 0.9345454545454546
# 0.9059929494712103

# %%
for x, y in zip(X_test, y_pred):
    for x_sent, y_sent in zip(x, y):
        print(x_sent[1], y_sent)
# Out:
# word.lower=le 0
# word.lower=gars 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=une 0
# word.lower=fille 0
# word.lower=0 0
# word.lower=j 0
# word.lower=' 0
# word.lower=avais 0
# word.lower=pas 0
# word.lower=le 0
# word.lower=match 0
# word.lower=d 0
# word.lower=' 0
# word.lower=adn 0
# word.lower=, 0
# word.lower=mais 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=reçu 0
# word.lower=son 0
# word.lower=dossier 0
# word.lower=dentaire 0
# word.lower=, 0
# word.lower=puis 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=ça 0
# word.lower=0 0
# word.lower=je 0
# word.lower=lui 0
# word.lower=ai 0
# word.lower=donné 0
# word.lower=une 0
# word.lower=brosse 0
# word.lower=à 0
# word.lower=dents 0
# word.lower=puis 0
# word.lower=une 0
# word.lower=surprise 0
# word.lower=0 0
# word.lower=0 0
# word.lower=elle 0
# word.lower=est 0
# word.lower=super 0
# word.lower=contente 0
# word.lower=0 0
# word.lower=0 0
# word.lower=jeff 0
# word.lower=, 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=qui 0
# word.lower=? 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=attends 0
# word.lower=un 0
# word.lower=peu 0
# word.lower=, 0
# word.lower=là 0
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=rita 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=beaumont 1
# word.lower=0 0
# word.lower=rita 1
# word.lower=beaumont 1
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=ordinaire 0
# word.lower=comme 0
# word.lower=nom 0
# word.lower=, 0
# word.lower=hein 0
# word.lower=? 0
# word.lower=rita 0
# word.lower=, 0
# word.lower=rita 0
# word.lower=la 0
# word.lower=barmaid 0
# word.lower=? 0
# word.lower=merci 0
# word.lower=, 0
# word.lower=jeff 0
# word.lower=0 0
# word.lower=hé 0
# word.lower=, 0
# word.lower=je 0
# word.lower=te 0
# word.lower=dis 0
# word.lower=ça 0
# word.lower=de 0
# word.lower=même 0
# word.lower=, 0
# word.lower=là 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=sais 0
# word.lower=que 0
# word.lower=rita 0
# word.lower=à 0
# word.lower=l 0
# word.lower=' 0
# word.lower=envers 0
# word.lower=, 0
# word.lower=euh 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=ça 0
# word.lower=fait 0
# word.lower=pun 0
# word.lower=: 0
# word.lower=cit 0
# word.lower=a 0
# word.lower=tir 0
# word.lower=pun 0
# word.lower=: 0
# word.lower=cit 0
# word.lower=0 0
# word.lower=en 0
# word.lower=tout 0
# word.lower=cas 0
# word.lower=! 0
# word.lower=merci 0
# word.lower=, 0
# word.lower=jeff 0
# word.lower=0 0
# word.lower=pas 0
# word.lower=de 0
# word.lower=trouble 0
# word.lower=0 0
# word.lower=0 0
# word.lower=that 1
# word.lower=would' 1
# word.lower=ve 1
# word.lower=been 1
# word.lower=helpful 1
# word.lower=to 1
# word.lower=know 1
# word.lower=0 0
# word.lower=0 0
# word.lower=fuck 1
# word.lower=0 0
# word.lower=she 1
# word.lower=was 1
# word.lower=trying 1
# word.lower=to 1
# word.lower=call 1
# word.lower=you 1
# word.lower=, 1
# word.lower=that' 0
# word.lower=s 0
# word.lower=why 1
# word.lower=0 0
# word.lower=therrien 0
# word.lower=must' 0
# word.lower=ve 0
# word.lower=known 1
# word.lower=and 1
# word.lower=gotten 1
# word.lower=rid 1
# word.lower=of 1
# word.lower=her 1
# word.lower=0 0
# word.lower=0 0
# word.lower=no 1
# word.lower=, 1
# word.lower=no 1
# word.lower=, 1
# word.lower=no 1
# word.lower=0 0
# word.lower=therrien 0
# word.lower=was 1
# word.lower=in 1
# word.lower=the 1
# word.lower=trunk 1
# word.lower=of 1
# word.lower=the 1
# word.lower=car 1
# word.lower=0 0
# word.lower=he 1
# word.lower=would' 1
# word.lower=ve 1
# word.lower=had 1
# word.lower=to 1
# word.lower=have 1
# word.lower=broken 1
# word.lower=out 1
# word.lower=of 1
# word.lower=the 1
# word.lower=trunk 1
# word.lower=, 1
# word.lower=stolen 1
# word.lower=a 1
# word.lower=car 1
# word.lower=, 1
# word.lower=driven 1
# word.lower=back 1
# word.lower=to 1
# word.lower=the 1
# word.lower=bar 1
# word.lower=, 1
# word.lower=grabbed 1
# word.lower=the 1
# word.lower=girl 1
# word.lower=, 1
# word.lower=grabbed 1
# word.lower=a 1
# word.lower=bomb 1
# word.lower=that 1
# word.lower=he 1
# word.lower=prepared 1
# word.lower=for 1
# word.lower=that 1
# word.lower=purpose 1
# word.lower=, 1
# word.lower=driven 1
# word.lower=back 1
# word.lower=to 1
# word.lower=your 1
# word.lower=car 1
# word.lower=, 1
# word.lower=put 1
# word.lower=her 1
# word.lower=in 1
# word.lower=the 1
# word.lower=trunk 1
# word.lower=, 1
# word.lower=and 1
# word.lower=then 1
# word.lower=rigged 1
# word.lower=the 1
# word.lower=bomb 1
# word.lower=? 1
# word.lower=the 1
# word.lower=show 1
# word.lower=wasn' 0
# word.lower=t 0
# word.lower=that 1
# word.lower=long 1
# word.lower=0 0
# word.lower=il 0
# word.lower=est 0
# word.lower=pas 0
# word.lower=tout 0
# word.lower=seul 0
# word.lower=0 0
# word.lower=oui 0
# word.lower=? 0
# word.lower=david 1
# word.lower=? 1
# word.lower=voyons 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=parles 0
# word.lower=d 0
# word.lower=' 0
# word.lower=une 0
# word.lower=heure 0
# word.lower=pour 0
# word.lower=appeler 0
# word.lower=! 0
# word.lower=comment 0
# word.lower=ça 0
# word.lower=va 0
# word.lower=à 0
# word.lower=la 0
# word.lower=maison 0
# word.lower=? 0
# word.lower=ça 0
# word.lower=va 0
# word.lower=0 0
# word.lower=t 0
# word.lower=' 0
# word.lower=es 0
# word.lower=bizarre 0
# word.lower=0 0
# word.lower=as 0
# word.lower=-tu 0
# word.lower=bu 0
# word.lower=? 0
# word.lower=je 0
# word.lower=sais 0
# word.lower=pas 0
# word.lower=, 0
# word.lower=on 0
# word.lower=dirait 0
# word.lower=que 0
# word.lower=je 0
# word.lower=m 0
# word.lower=' 0
# word.lower=ennuie 0
# word.lower=, 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=les 0
# word.lower=blues 0
# word.lower=0 0
# word.lower=passe 0
# word.lower=-moi 0
# word.lower=donc 0
# word.lower=gabrielle 0
# word.lower=0 0
# word.lower=david 0
# word.lower=, 0
# word.lower=gabrielle 0
# word.lower=, 0
# word.lower=elle 0
# word.lower=dort 0
# word.lower=, 0
# word.lower=là 0
# word.lower=0 0
# word.lower=comme 0
# word.lower=n 0
# word.lower=' 0
# word.lower=importe 0
# word.lower=qui 0
# word.lower=de 0
# word.lower=normal 0
# word.lower=à 0
# word.lower=cette 0
# word.lower=heure 0
# word.lower=-ci 0
# word.lower=0 0
# word.lower=je 0
# word.lower=sais 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=je 0
# word.lower=sais 0
# word.lower=pas 0
# word.lower=, 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=juste 0
# word.lower=besoin 0
# word.lower=d 0
# word.lower=' 0
# word.lower=entendre 0
# word.lower=sa 0
# word.lower=voix 0
# word.lower=0 0
# word.lower=hé 0
# word.lower=, 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=est 0
# word.lower=-ce 0
# word.lower=que 0
# word.lower=tu 0
# word.lower=me 0
# word.lower=dis 0
# word.lower=pas 0
# word.lower=, 0
# word.lower=là 0
# word.lower=? 0
# word.lower=s 0
# word.lower=' 0
# word.lower=il 0
# word.lower=te 0
# word.lower=plaît 0
# word.lower=, 0
# word.lower=suzie 0
# word.lower=0 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=est 0
# word.lower=-ce 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=il 0
# word.lower=y 0
# word.lower=a 0
# word.lower=? 0
# word.lower=ok 0
# word.lower=! 0
# word.lower=ok 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=y 0
# word.lower=vais 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=y 0
# word.lower=vais 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=arrive 0
# word.lower=en 0
# word.lower=haut 0
# word.lower=0 0
# word.lower=elle 0
# word.lower=s 0
# word.lower=' 0
# word.lower=est 0
# word.lower=couchée 0
# word.lower=dans 0
# word.lower=ta 0
# word.lower=chambre 0
# word.lower=0 0
# word.lower=elle 0
# word.lower=aussi 0
# word.lower=, 0
# word.lower=elle 0
# word.lower=s 0
# word.lower=' 0
# word.lower=ennuyait 0
# word.lower=0 0
# word.lower=david 1
# word.lower=! 1
# word.lower=la 0
# word.lower=porte 0
# word.lower=est 0
# word.lower=ouverte 0
# word.lower=! 0
# word.lower=elle 0
# word.lower=est 0
# word.lower=partie 0
# word.lower=! 0
# word.lower=elle 0
# word.lower=est 0
# word.lower=pas 0
# word.lower=là 0
# word.lower=! 0
# word.lower=je 0
# word.lower=l 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=couchée 0
# word.lower=tantôt 0
# word.lower=! 0
# word.lower=elle 0
# word.lower=est 0
# word.lower=pas 0
# word.lower=là 0
# word.lower=! 0
# word.lower=elle 0
# word.lower=est 0
# word.lower=partie 0
# word.lower=! 0
# word.lower=david 0
# word.lower=! 0
# word.lower=0 0
# word.lower=hello 1
# word.lower=? 1
# word.lower=0 0
# word.lower=who 1
# word.lower=is 1
# word.lower=this 1
# word.lower=? 1
# word.lower=0 0
# word.lower=oh 1
# word.lower=, 1
# word.lower=it' 0
# word.lower=s 0
# word.lower=detective 1
# word.lower=ward 1
# word.lower=0 0
# word.lower=i 1
# word.lower=have 1
# word.lower=a 1
# word.lower=call 1
# word.lower=for 1
# word.lower=mr 1
# word.lower=0 0
# word.lower=david 1
# word.lower=bouchard 1
# word.lower=from 1
# word.lower=his 1
# word.lower=daughter 1
# word.lower=0 0
# word.lower=is 1
# word.lower=he 1
# word.lower=available 1
# word.lower=? 1
# word.lower=si 0
# word.lower=tu 0
# word.lower=touches 0
# word.lower=à 0
# word.lower=mon 0
# word.lower=bébé 0
# word.lower=, 0
# word.lower=je 0
# word.lower=te 0
# word.lower=tue 0
# word.lower=, 0
# word.lower=mon 0
# word.lower=tabarnak 0
# word.lower=! 0
# word.lower=0 0
# word.lower=your 1
# word.lower=daughter 1
# word.lower=is 1
# word.lower=fine 1
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=ton 0
# word.lower=père 0
# word.lower=, 0
# word.lower=gabrielle 0
# word.lower=0 0
# word.lower=papa 1
# word.lower=, 1
# word.lower=viens 1
# word.lower=me 1
# word.lower=chercher 1
# word.lower=! 1
# word.lower=s 0
# word.lower=' 0
# word.lower=il 0
# word.lower=te 0
# word.lower=plaît 0
# word.lower=, 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=peur 0
# word.lower=! 0
# word.lower=papa 0
# word.lower=, 0
# word.lower=aide 0
# word.lower=-moi 0
# word.lower=! 0
# word.lower=0 0
# word.lower=shut 1
# word.lower=up 1
# word.lower=! 1
# word.lower=i 1
# word.lower=have 1
# word.lower=nothing 1
# word.lower=against 1
# word.lower=your 1
# word.lower=daughter 1
# word.lower=0 0
# word.lower=mais 0
# word.lower=toi 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=commences 0
# word.lower=sérieusement 0
# word.lower=à 0
# word.lower=me 0
# word.lower=faire 0
# word.lower=chier 0
# word.lower=0 0
# word.lower=que 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=que 0
# word.lower=tu 0
# word.lower=veux 0
# word.lower=? 0
# word.lower=0 0
# word.lower=i 1
# word.lower=assume 1
# word.lower=that 1
# word.lower=a 1
# word.lower=smart 1
# word.lower=fellow 1
# word.lower=like 1
# word.lower=you 1
# word.lower=would 1
# word.lower=know 1
# word.lower=who' 0
# word.lower=s 0
# word.lower=next 1
# word.lower=on 1
# word.lower=my 1
# word.lower=list 1
# word.lower=0 0
# word.lower=stay 1
# word.lower=out 1
# word.lower=of 1
# word.lower=my 1
# word.lower=way 1
# word.lower=0 0
# word.lower=let 1
# word.lower=me 1
# word.lower=do 1
# word.lower=my 1
# word.lower=grand 1
# word.lower=finale 1
# word.lower=0 0
# word.lower=puis 0
# word.lower=après 0
# word.lower=tu 0
# word.lower=retrouves 0
# word.lower=ta 0
# word.lower=fille 0
# word.lower=safe 1
# word.lower=and 1
# word.lower=sound 1
# word.lower=0 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=a 0
# word.lower=rien 0
# word.lower=à 0
# word.lower=voir 0
# word.lower=là-dedans 0
# word.lower=0 0
# word.lower=prends 0
# word.lower=-moi 0
# word.lower=à 0
# word.lower=la 0
# word.lower=place 0
# word.lower=0 0
# word.lower=true 0
# word.lower=! 0
# word.lower=and 1
# word.lower=it 1
# word.lower=wouldn' 0
# word.lower=t 0
# word.lower=be 1
# word.lower=right 1
# word.lower=for 1
# word.lower=anything 1
# word.lower=bad 1
# word.lower=to 1
# word.lower=happen 1
# word.lower=to 1
# word.lower=her 1
# word.lower=0 0
# word.lower=à 0
# word.lower=cause 0
# word.lower=de 0
# word.lower=toi 0
# word.lower=0 0
# word.lower=suzie 0
# word.lower=0 0
# word.lower=je 0
# word.lower=veux 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=comprends 0
# word.lower=-tu 0
# word.lower=? 0
# word.lower=! 0
# word.lower=va 0
# word.lower=la 0
# word.lower=chercher 0
# word.lower=! 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=est 0
# word.lower=-ce 0
# word.lower=qui 0
# word.lower=va 0
# word.lower=arriver 0
# word.lower=? 0
# word.lower=dis 0
# word.lower=-moi 0
# word.lower=! 0
# word.lower=dis 0
# word.lower=-moi 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=est 0
# word.lower=-ce 0
# word.lower=qui 0
# word.lower=va 0
# word.lower=arriver 0
# word.lower=! 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=est 0
# word.lower=-ce 0
# word.lower=que 0
# word.lower=t 0
# word.lower=' 0
# word.lower=as 0
# word.lower=fait 0
# word.lower=? 0
# word.lower=touche 0
# word.lower=-moi 0
# word.lower=pas 0
# word.lower=! 0
# word.lower=touche 0
# word.lower=- 0
# word.lower=moi 0
# word.lower=pas 0
# word.lower=! 0
# word.lower=touche 0
# word.lower=- 0
# word.lower=moi 0
# word.lower=pas 0
# word.lower=! 0
# word.lower=je 0
# word.lower=veux 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=! 0
# word.lower=tu 0
# word.lower=comprends 0
# word.lower=- 0
# word.lower=tu 0
# word.lower=? 0
# word.lower=si 0
# word.lower=jamais 0
# word.lower=il 0
# word.lower=y 0
# word.lower=touche 0
# word.lower=! 0
# word.lower=s 0
# word.lower=' 0
# word.lower=il 0
# word.lower=y 0
# word.lower=touche 0
# word.lower=, 0
# word.lower=je 0
# word.lower=veux 0
# word.lower=plus 0
# word.lower=jamais 0
# word.lower=te 0
# word.lower=voir 0
# word.lower=, 0
# word.lower=mon 0
# word.lower=hostie 0
# word.lower=! 0
# word.lower=je 0
# word.lower=m 0
# word.lower=' 0
# word.lower=excuse 0
# word.lower=0 0
# word.lower=je 0
# word.lower=m 0
# word.lower=' 0
# word.lower=excuse 0
# word.lower=0 0
# word.lower=je 0
# word.lower=m 0
# word.lower=' 0
# word.lower=excuse 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=va 0
# word.lower=chercher 0
# word.lower=notre 0
# word.lower=fille 0
# word.lower=! 0
# word.lower=ramène 0
# word.lower=-nous 0
# word.lower=notre 0
# word.lower=bébé 0
# word.lower=0 0
# word.lower=ok 0
# word.lower=0 0
# word.lower=0 0
# word.lower=is 1
# word.lower=she 1
# word.lower=okay 1
# word.lower=? 1
# word.lower=tout 0
# word.lower=est 0
# word.lower=là 0
# word.lower=, 0
# word.lower=comme 0
# word.lower=t 0
# word.lower=' 0
# word.lower=avais 0
# word.lower=demandé 0
# word.lower=0 0
# word.lower=je 0
# word.lower=peux 0
# word.lower=-tu 0
# word.lower=faire 0
# word.lower=d 0
# word.lower=' 0
# word.lower=autre 0
# word.lower=chose 0
# word.lower=? 0
# word.lower=occupe 0
# word.lower=-toi 0
# word.lower=de 0
# word.lower=suzie 0
# word.lower=, 0
# word.lower=s 0
# word.lower=' 0
# word.lower=il 0
# word.lower=te 0
# word.lower=plaît 0
# word.lower=0 0
# word.lower=0 0
# word.lower=we 1
# word.lower=have 1
# word.lower=to 1
# word.lower=go 1
# word.lower=0 0
# word.lower=let 1
# word.lower=me 1
# word.lower=drive 1
# word.lower=0 0
# word.lower=0 0
# word.lower=give 1
# word.lower=me 1
# word.lower=some 1
# word.lower=privacy 1
# word.lower=0 0
# word.lower=0 0
# word.lower=okay 1
# word.lower=, 1
# word.lower=boss 1
# word.lower=0 0
# word.lower=hé 0
# word.lower=! 0
# word.lower=hé 0
# word.lower=! 0
# word.lower=ça 0
# word.lower=commence 0
# word.lower=-tu 0
# word.lower=, 0
# word.lower=votre 0
# word.lower=affaire 0
# word.lower=? 0
# word.lower=il 0
# word.lower=y 0
# word.lower=en 0
# word.lower=a 0
# word.lower=qui 0
# word.lower=ont 0
# word.lower=des 0
# word.lower=deadlines 0
# word.lower=0 0
# word.lower=si 0
# word.lower=vous 0
# word.lower=voulez 0
# word.lower=qu 0
# word.lower=' 0
# word.lower=on 0
# word.lower=en 0
# word.lower=parle 0
# word.lower=avant 0
# word.lower=la 0
# word.lower=saison 0
# word.lower=, 0
# word.lower=il 0
# word.lower=faut 0
# word.lower=activer 0
# word.lower=0 0
# word.lower=0 0
# word.lower=sorry 1
# word.lower=for 1
# word.lower=the 1
# word.lower=delay 1
# word.lower=, 1
# word.lower=everyone 1
# word.lower=0 0
# word.lower=mr 1
# word.lower=0 0
# word.lower=buttman 1
# word.lower=will 1
# word.lower=be 1
# word.lower=here 1
# word.lower=any 1
# word.lower=minute 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you 1
# word.lower=sure 1
# word.lower=you 1
# word.lower=want 1
# word.lower=to 1
# word.lower=do 1
# word.lower=this 1
# word.lower=? 1
# word.lower=0 0
# word.lower=remember 1
# word.lower=, 1
# word.lower=it 1
# word.lower=was 1
# word.lower=my 1
# word.lower=idea 1
# word.lower=0 0
# word.lower=i 1
# word.lower=just 1
# word.lower=don' 0
# word.lower=t 0
# word.lower=want 1
# word.lower=to 1
# word.lower=read 1
# word.lower=about 1
# word.lower=it 1
# word.lower=in 0
# word.lower=tomorrow' 0
# word.lower=s 0
# word.lower=papers 1
# word.lower=0 0
# word.lower=0 0
# word.lower=mr 1
# word.lower=0 0
# word.lower=arbusto 1
# word.lower=! 1
# word.lower=0 0
# word.lower=hey 1
# word.lower=, 1
# word.lower=buttman 1
# word.lower=! 1
# word.lower=0 0
# word.lower=so 1
# word.lower=nice 1
# word.lower=to 1
# word.lower=talk 1
# word.lower=to 1
# word.lower=you 1
# word.lower=again 1
# word.lower=0 0
# word.lower=0 0
# word.lower=everything 1
# word.lower=coming 1
# word.lower=together 1
# word.lower=? 1
# word.lower=0 0
# word.lower=sure 1
# word.lower=is 1
# word.lower=0 0
# word.lower=0 0
# word.lower=i 1
# word.lower=don' 0
# word.lower=t 0
# word.lower=want 1
# word.lower=you 1
# word.lower=to 1
# word.lower=misunderestimate 1
# word.lower=how 1
# word.lower=grateful 1
# word.lower=i 1
# word.lower=am 1
# word.lower=0 0
# word.lower=i' 0
# word.lower=m 0
# word.lower=sending 1
# word.lower=you 1
# word.lower=our 1
# word.lower=agreement 1
# word.lower=right 1
# word.lower=now 1
# word.lower=0 0
# word.lower=you' 0
# word.lower=re 0
# word.lower=doing 1
# word.lower=a 1
# word.lower=wonderful 1
# word.lower=thing 1
# word.lower=for 1
# word.lower=hockey 1
# word.lower=0 0
# word.lower=cause 1
# word.lower=i' 0
# word.lower=m 0
# word.lower=gonna 1
# word.lower=make 1
# word.lower=hockey 1
# word.lower=as 1
# word.lower=texas 1
# word.lower=as 1
# word.lower=a 1
# word.lower=big 1
# word.lower=, 1
# word.lower=fat 1
# word.lower=american 1
# word.lower=steak 1
# word.lower=0 0
# word.lower=none 1
# word.lower=of 1
# word.lower=that 1
# word.lower=poison 1
# word.lower=canadian 1
# word.lower=shit 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you' 0
# word.lower=re 0
# word.lower=going 1
# word.lower=to 1
# word.lower=enjoy 1
# word.lower=having 1
# word.lower=a 1
# word.lower=top 1
# word.lower=hockey 1
# word.lower=team 1
# word.lower=in 1
# word.lower=your 1
# word.lower=state 1
# word.lower=0 0
# word.lower=i' 0
# word.lower=m 0
# word.lower=busy 1
# word.lower=here 1
# word.lower=! 1
# word.lower=just 1
# word.lower=a 1
# word.lower=sec 1
# word.lower=0 0
# word.lower=you 1
# word.lower=idiots 1
# word.lower=! 1
# word.lower=who 1
# word.lower=the 1
# word.lower=hell 1
# word.lower=are 1
# word.lower=you 1
# word.lower=? 1
# word.lower=0 0
# word.lower=buttman 1
# word.lower=? 1
# word.lower=0 0
# word.lower=what' 0
# word.lower=s 0
# word.lower=going 1
# word.lower=on 1
# word.lower=? 1
# word.lower=0 0
# word.lower=what 1
# word.lower=the 1
# word.lower=hell' 0
# word.lower=s 0
# word.lower=going 1
# word.lower=on 1
# word.lower=there 1
# word.lower=? 1
# word.lower=! 0
# word.lower=0 0
# word.lower=get 1
# word.lower=in 1
# word.lower=the 1
# word.lower=bag 1
# word.lower=0 0
# word.lower=0 0
# word.lower=buttman 1
# word.lower=? 1
# word.lower=dans 0
# word.lower=la 0
# word.lower=poche 0
# word.lower=0 0
# word.lower=comment 0
# word.lower=ça 0
# word.lower=marche 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=calice 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=0 0
# word.lower=have 1
# word.lower=a 1
# word.lower=look 1
# word.lower=at 1
# word.lower=this 1
# word.lower=0 0
# word.lower=0 0
# word.lower=are 1
# word.lower=you 1
# word.lower=talking 1
# word.lower=to 1
# word.lower=me 1
# word.lower=? 1
# word.lower=are 1
# word.lower=you 1
# word.lower=talking 1
# word.lower=to 1
# word.lower=me 1
# word.lower=? 1
# word.lower=are 1
# word.lower=you 1
# word.lower=talking 1
# word.lower=to 1
# word.lower=me 1
# word.lower=? 1
# word.lower=aha 0
# word.lower=! 0
# word.lower=are 1
# word.lower=you 1
# word.lower=talking 1
# word.lower=to 1
# word.lower=me 1
# word.lower=? 1
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=bon 0
# word.lower=, 0
# word.lower=ça 0
# word.lower=0 0
# word.lower=ah 0
# word.lower=, 0
# word.lower=tabarnak 0
# word.lower=! 0
# word.lower=tabarnak 0
# word.lower=! 0
# word.lower=are 1
# word.lower=you 1
# word.lower=talking 1
# word.lower=to 1
# word.lower=me 1
# word.lower=? 1
# word.lower=0 0
# word.lower=argh 0
# word.lower=! 0
# word.lower=ah 0
# word.lower=! 0
# word.lower=0 0
# word.lower=don' 0
# word.lower=t 0
# word.lower=you 1
# word.lower=know 1
# word.lower=who 1
# word.lower=i 1
# word.lower=am 1
# word.lower=? 1
# word.lower=i' 0
# word.lower=m 0
# word.lower=gonna 0
# word.lower=sue 0
# word.lower=your 0
# word.lower=asses 0
# word.lower=! 0
# word.lower=you 1
# word.lower=can' 0
# word.lower=t 0
# word.lower=put 1
# word.lower=me 1
# word.lower=in 1
# word.lower=the 1
# word.lower=trunk 1
# word.lower=of 1
# word.lower=a 1
# word.lower=car 1
# word.lower=! 1
# word.lower=0 0
# word.lower=yes 1
# word.lower=, 1
# word.lower=i 1
# word.lower=can 1
# word.lower=0 0
# word.lower=it' 0
# word.lower=s 0
# word.lower=a 1
# word.lower=quebec 1
# word.lower=tradition 1
# word.lower=0 0
# word.lower=0 0
# word.lower=okay 1
# word.lower=, 1
# word.lower=i' 0
# word.lower=m 0
# word.lower=in 1
# word.lower=place 1
# word.lower=0 0
# word.lower=calice 1
# word.lower=! 1
# word.lower=va-t'en 0
# word.lower=là-bas 0
# word.lower=0 0
# word.lower=va-t'en 0
# word.lower=là-bas 0
# word.lower=, 0
# word.lower=là 0
# word.lower=! 0
# word.lower=amène 0
# word.lower=tes 0
# word.lower=flos 0
# word.lower=là-bas 0
# word.lower=! 0
# word.lower=0 0
# word.lower=bien 0
# word.lower=là 0
# word.lower=, 0
# word.lower=franchement 0
# word.lower=! 0
# word.lower=0 0
# word.lower=occupe 0
# word.lower=-toi 0
# word.lower=de 0
# word.lower=tes 0
# word.lower=enfants 0
# word.lower=! 0
# word.lower=excusez 0
# word.lower=0 0
# word.lower=testing 1
# word.lower=.. 0
# word.lower=0 0
# word.lower=, 0
# word.lower=, 0
# word.lower=... 0
# word.lower=0 0
# word.lower=what 1
# word.lower=do 1
# word.lower=you 1
# word.lower=think 1
# word.lower=you' 0
# word.lower=re 0
# word.lower=doing 1
# word.lower=? 1
# word.lower=0 0
# word.lower=police 1
# word.lower=business 1
# word.lower=0 0
# word.lower=votre 0
# word.lower=attention 0
# word.lower=, 0
# word.lower=s 0
# word.lower=' 0
# word.lower=il 0
# word.lower=vous 0
# word.lower=plaît 0
# word.lower=0 0
# word.lower=he' 0
# word.lower=s 0
# word.lower=had 1
# word.lower=an 1
# word.lower=unfortunate 1
# word.lower=contretemps 1
# word.lower=, 1
# word.lower=and 1
# word.lower=therefore 1
# word.lower=, 1
# word.lower=the 1
# word.lower=press 1
# word.lower=conference 1
# word.lower=is 1
# word.lower=cancelled 1
# word.lower=0 0
# word.lower=lf 1
# word.lower=there' 0
# word.lower=s 0
# word.lower=any 1
# word.lower=more 1
# word.lower=information 1
# word.lower=before 0
# word.lower=tonight' 0
# word.lower=s 0
# word.lower=final 1
# word.lower=game 1
# word.lower=, 1
# word.lower=you' 0
# word.lower=ll 0
# word.lower=get 1
# word.lower=it 0
# word.lower=. 0
# word.lower=on 0
# word.lower=vous 0
# word.lower=tiendra 0
# word.lower=au 0
# word.lower=courant 0
# word.lower=0 0
# word.lower=merci 0
# word.lower=0 0
# word.lower=hé 0
# word.lower=! 0
# word.lower=ça 0
# word.lower=marche 0
# word.lower=pas 0
# word.lower=de 0
# word.lower=même 0
# word.lower=! 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=quoi 0
# word.lower=, 0
# word.lower=le 0
# word.lower=contretemps 0
# word.lower=? 0
# word.lower=il 0
# word.lower=se 0
# word.lower=fout 0
# word.lower=des 0
# word.lower=canadiens 0
# word.lower=français 0
# word.lower=? 0
# word.lower=not 1
# word.lower=just 1
# word.lower=the 1
# word.lower=french 1
# word.lower=0 0
# word.lower=i 1
# word.lower=don' 0
# word.lower=t 0
# word.lower=think 1
# word.lower=he 1
# word.lower=much 1
# word.lower=likes 1
# word.lower=canadians 1
# word.lower=, 1
# word.lower=period 1
# word.lower=0 0
# word.lower=no 1
# word.lower=further 1
# word.lower=comment 1
# word.lower=0 0
# word.lower=they' 0
# word.lower=re 0
# word.lower=all 1
# word.lower=yours 1
# word.lower=0 0
# word.lower=ladies 1
# word.lower=and 1
# word.lower=gentlemen 1
# word.lower=, 1
# word.lower=mesdames 0
# word.lower=et 0
# word.lower=messieurs 0
# word.lower=0 0
# word.lower=... 1
# word.lower=we 1
# word.lower=apologize 1
# word.lower=for 1
# word.lower=the 1
# word.lower=delay 1
# word.lower=0 0
# word.lower=nous 0
# word.lower=nous 0
# word.lower=excusons 0
# word.lower=pour 0
# word.lower=ce 0
# word.lower=délai 0
# word.lower=0 0
# word.lower=0 0
# word.lower=how' 1
# word.lower=d 1
# word.lower=i 1
# word.lower=do 1
# word.lower=? 1
# word.lower=great 1
# word.lower=! 1
# word.lower=mais 0
# word.lower=t 0
# word.lower=' 0
# word.lower=es 0
# word.lower=suivi 0
# word.lower=0 0
# word.lower=don' 0
# word.lower=t 0
# word.lower=turn 1
# word.lower=around 1
# word.lower=0 0
# word.lower=0 0
# word.lower=how 1
# word.lower=many 1
# word.lower=? 1
# word.lower=one 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=la 0
# word.lower=mascotte 0
# word.lower=des 0
# word.lower=patriotes 0
# word.lower=0 0
# word.lower=attire 0
# word.lower=-le 0
# word.lower=en 0
# word.lower=bas 0
# word.lower=, 0
# word.lower=je 0
# word.lower=te 0
# word.lower=suis 0
# word.lower=0 0
# word.lower=0 0
# word.lower=got 1
# word.lower=it 1
# word.lower=. 1
# word.lower=okay 1
# word.lower=0 0
# word.lower=calice 0
# word.lower=de 0
# word.lower=tabarnak 0
# word.lower=! 0
# word.lower=calice 1
# word.lower=! 1
# word.lower=crisse 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=tabarnak 0
# word.lower=! 0
# word.lower=bouchard 1
# word.lower=0 0
# word.lower=je 0
# word.lower=t 0
# word.lower=' 0
# word.lower=avais 0
# word.lower=dit 0
# word.lower=de 0
# word.lower=te 0
# word.lower=tenir 0
# word.lower=loin 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=veux 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=un 0
# word.lower=dernier 0
# word.lower=mot 0
# word.lower=avec 0
# word.lower=ta 0
# word.lower=fille 0
# word.lower=? 0
# word.lower=attends 1
# word.lower=! 1
# word.lower=attends 1
# word.lower=! 1
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=buttman 0
# word.lower=0 0
# word.lower=si 0
# word.lower=tu 0
# word.lower=le 0
# word.lower=veux 0
# word.lower=, 0
# word.lower=je 0
# word.lower=te 0
# word.lower=le 0
# word.lower=donne 0
# word.lower=0 0
# word.lower=je 0
# word.lower=veux 0
# word.lower=juste 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=0 0
# word.lower=t 0
# word.lower=' 0
# word.lower=en 0
# word.lower=demandes 0
# word.lower=pas 0
# word.lower=mal 0
# word.lower=, 0
# word.lower=david 0
# word.lower=0 0
# word.lower=ouais 0
# word.lower=, 0
# word.lower=ouais 0
# word.lower=0 0
# word.lower=on 0
# word.lower=a 0
# word.lower=-tu 0
# word.lower=un 0
# word.lower=deal 0
# word.lower=? 0
# word.lower=le 0
# word.lower=vieux-port 0
# word.lower=0 0
# word.lower=la 0
# word.lower=tour 0
# word.lower=au 0
# word.lower=bout 0
# word.lower=du 0
# word.lower=quai 0
# word.lower=des 0
# word.lower=convoyeurs 0
# word.lower=0 0
# word.lower=you 1
# word.lower=have 1
# word.lower=minutes 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you 1
# word.lower=could 1
# word.lower=lose 1
# word.lower=your 1
# word.lower=job 1
# word.lower=over 1
# word.lower=this 1
# word.lower=0 0
# word.lower=je 0
# word.lower=m 0
# word.lower=' 0
# word.lower=en 0
# word.lower=calice 0
# word.lower=0 0
# word.lower=ouais 0
# word.lower=? 0
# word.lower=0 0
# word.lower=bring 1
# word.lower=him 1
# word.lower=inside 1
# word.lower=the 1
# word.lower=boat 1
# word.lower=0 0
# word.lower=tu 0
# word.lower=vas 0
# word.lower=voir 0
# word.lower=, 0
# word.lower=mon 0
# word.lower=hostie 0
# word.lower=, 0
# word.lower=t 0
# word.lower=' 0
# word.lower=as 0
# word.lower=pas 0
# word.lower=fini 0
# word.lower=avec 0
# word.lower=moi 0
# word.lower=0 0
# word.lower=0 0
# word.lower=hey 1
# word.lower=, 1
# word.lower=welcome 1
# word.lower=home 1
# word.lower=, 1
# word.lower=therrien 0
# word.lower=0 0
# word.lower=you 1
# word.lower=were 1
# word.lower=born 1
# word.lower=to 1
# word.lower=be 1
# word.lower=a 1
# word.lower=mascot 1
# word.lower=0 0
# word.lower=as 0
# word.lower=-tu 0
# word.lower=fini 0
# word.lower=de 0
# word.lower=me 0
# word.lower=piler 0
# word.lower=sur 0
# word.lower=les 0
# word.lower=raquettes 0
# word.lower=, 0
# word.lower=crisse 0
# word.lower=? 0
# word.lower=ta 0
# word.lower=gueule 0
# word.lower=puis 0
# word.lower=avance 0
# word.lower=0 0
# word.lower=0 0
# word.lower=where 1
# word.lower=the 1
# word.lower=fuck 1
# word.lower=is 1
# word.lower=my 1
# word.lower=player 1
# word.lower=? 1
# word.lower=arrête 0
# word.lower=-toi 0
# word.lower=là 0
# word.lower=0 0
# word.lower=il 0
# word.lower=est 0
# word.lower=où 0
# word.lower=, 0
# word.lower=buttman 0
# word.lower=? 0
# word.lower=il 0
# word.lower=y 0
# word.lower=a 0
# word.lower=un 0
# word.lower=changement 0
# word.lower=au 0
# word.lower=programme 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=me 0
# word.lower=donnes 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=, 0
# word.lower=toi 0
# word.lower=puis 0
# word.lower=ton 0
# word.lower=chum 0
# word.lower=, 0
# word.lower=vous 0
# word.lower=pouvez 0
# word.lower=partir 0
# word.lower=tranquilles 0
# word.lower=0 0
# word.lower=papa 1
# word.lower=! 1
# word.lower=tu 0
# word.lower=vois 0
# word.lower=? 0
# word.lower=moi 0
# word.lower=, 0
# word.lower=je 0
# word.lower=suis 0
# word.lower=un 0
# word.lower=gars 0
# word.lower=de 0
# word.lower=parole 0
# word.lower=0 0
# word.lower=papa 1
# word.lower=, 1
# word.lower=viens 1
# word.lower=me 1
# word.lower=chercher 1
# word.lower=, 1
# word.lower=j 0
# word.lower=' 0
# word.lower=aime 0
# word.lower=pas 0
# word.lower=ça 0
# word.lower=, 0
# word.lower=ici 0
# word.lower=! 0
# word.lower=0 0
# word.lower=ma 0
# word.lower=puce 0
# word.lower=, 0
# word.lower=papa 0
# word.lower=est 0
# word.lower=là 0
# word.lower=0 0
# word.lower=0 0
# word.lower=je 0
# word.lower=veux 0
# word.lower=m 0
# word.lower=' 0
# word.lower=en 0
# word.lower=aller 0
# word.lower=! 0
# word.lower=pleure 0
# word.lower=pas 0
# word.lower=, 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=presque 0
# word.lower=fini 0
# word.lower=0 0
# word.lower=0 0
# word.lower=oh 1
# word.lower=, 1
# word.lower=you' 0
# word.lower=re 0
# word.lower=so 1
# word.lower=cute 1
# word.lower=0 0
# word.lower=so 1
# word.lower=you 1
# word.lower=think 1
# word.lower=this 1
# word.lower=is 1
# word.lower=a 1
# word.lower=fair 1
# word.lower=trade 1
# word.lower=? 1
# word.lower=that' 0
# word.lower=s 0
# word.lower=not 1
# word.lower=what 1
# word.lower=we 1
# word.lower=agreed 1
# word.lower=on 1
# word.lower=0 0
# word.lower=you 1
# word.lower=should' 1
# word.lower=ve 1
# word.lower=brought 1
# word.lower=something 1
# word.lower=valuable 1
# word.lower=to 1
# word.lower=me 1
# word.lower=0 0
# word.lower=0 0
# word.lower=fuck 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=papa 1
# word.lower=! 1
# word.lower=j 0
# word.lower=' 0
# word.lower=aime 0
# word.lower=pas 0
# word.lower=ça 0
# word.lower=! 0
# word.lower=papa 1
# word.lower=, 1
# word.lower=viens 1
# word.lower=me 1
# word.lower=chercher 1
# word.lower=! 1
# word.lower=0 0
# word.lower=ferme 0
# word.lower=tes 0
# word.lower=yeux 0
# word.lower=, 0
# word.lower=gabrielle 0
# word.lower=0 0
# word.lower=0 0
# word.lower=viens 0
# word.lower=me 0
# word.lower=chercher 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=ferme 1
# word.lower=tes 1
# word.lower=yeux 1
# word.lower=, 1
# word.lower=gabrielle 1
# word.lower=! 1
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=ça 0
# word.lower=, 0
# word.lower=jusqu 0
# word.lower=' 0
# word.lower=à 0
# word.lower=temps 0
# word.lower=que 0
# word.lower=je 0
# word.lower=te 0
# word.lower=dise 0
# word.lower=de 0
# word.lower=les 0
# word.lower=ouvrir 0
# word.lower=0 0
# word.lower=0 0
# word.lower=throw 1
# word.lower=me 1
# word.lower=your 1
# word.lower=gun 1
# word.lower=0 0
# word.lower=now 1
# word.lower=! 1
# word.lower=crisse 0
# word.lower=, 0
# word.lower=t 0
# word.lower=' 0
# word.lower=es 0
# word.lower=malade 0
# word.lower=0 0
# word.lower=ah 1
# word.lower=, 1
# word.lower=david 1
# word.lower=! 1
# word.lower=c 0
# word.lower=' 0
# word.lower=était 0
# word.lower=un 0
# word.lower=fucked 0
# word.lower=- 0
# word.lower=up 0
# word.lower=loser 0
# word.lower=que 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=trouvé 0
# word.lower=sur 0
# word.lower=internet 0
# word.lower=0 0
# word.lower=he 1
# word.lower=wanted 1
# word.lower=revenge 1
# word.lower=on 1
# word.lower=those 1
# word.lower=who 1
# word.lower=screwed 1
# word.lower=up 1
# word.lower=his 1
# word.lower=hockey 1
# word.lower=career 1
# word.lower=with 1
# word.lower=the 1
# word.lower=pros 1
# word.lower=0 0
# word.lower=puis 0
# word.lower=moi 0
# word.lower=, 0
# word.lower=je 0
# word.lower=lui 0
# word.lower=ai 0
# word.lower=donné 0
# word.lower=les 0
# word.lower=outils 0
# word.lower=pour 0
# word.lower=le 0
# word.lower=faire 0
# word.lower=0 0
# word.lower=facile 0
# word.lower=, 0
# word.lower=hein 0
# word.lower=? 0
# word.lower=après 0
# word.lower=, 0
# word.lower=c 0
# word.lower=' 0
# word.lower=était 0
# word.lower=bien 0
# word.lower=easy 0
# word.lower=de 0
# word.lower=l 0
# word.lower=' 0
# word.lower=embarquer 0
# word.lower=pour 0
# word.lower=tuer 0
# word.lower=les 0
# word.lower=autres 0
# word.lower=fuckers 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=qui 0
# word.lower=ont 0
# word.lower=détruit 0
# word.lower=notre 0
# word.lower=great 0
# word.lower=game 0
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=juste 0
# word.lower=une 0
# word.lower=game 0
# word.lower=, 0
# word.lower=le 0
# word.lower=kid 0
# word.lower=0 0
# word.lower=0 0
# word.lower=give 1
# word.lower=me 1
# word.lower=your 1
# word.lower=car 1
# word.lower=keys 1
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=le 0
# word.lower=détective 0
# word.lower=ward 0
# word.lower=qui 0
# word.lower=a 0
# word.lower=mon 0
# word.lower=package 0
# word.lower=? 0
# word.lower=i 1
# word.lower=hope 1
# word.lower=he' 0
# word.lower=s 0
# word.lower=not 1
# word.lower=too 1
# word.lower=far 1
# word.lower=0 0
# word.lower=0 0
# word.lower=martin 0
# word.lower=! 0
# word.lower=bring 1
# word.lower=him 1
# word.lower=! 1
# word.lower=0 0
# word.lower=i' 0
# word.lower=m 0
# word.lower=coming 1
# word.lower=! 1
# word.lower=he 0
# word.lower=won' 0
# word.lower=t 0
# word.lower=kill 1
# word.lower=you 1
# word.lower=here 1
# word.lower=0 0
# word.lower=he 1
# word.lower=needs 1
# word.lower=a 1
# word.lower=crowd 1
# word.lower=and 1
# word.lower=you 1
# word.lower=need 1
# word.lower=a 1
# word.lower=tattoo 1
# word.lower=0 0
# word.lower=get 1
# word.lower=moving 1
# word.lower=0 0
# word.lower=0 0
# word.lower=c 0
# word.lower=' 0
# word.lower=est 0
# word.lower=trop 0
# word.lower=long 0
# word.lower=! 0
# word.lower=0 0
# word.lower=touche 0
# word.lower=pas 0
# word.lower=à 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=0 0
# word.lower=papa 1
# word.lower=! 1
# word.lower=dans 0
# word.lower=minutes 0
# word.lower=, 0
# word.lower=ça 0
# word.lower=saute 0
# word.lower=! 0
# word.lower=0 0
# word.lower=martin 0
# word.lower=, 0
# word.lower=move 0
# word.lower=! 0
# word.lower=0 0
# word.lower=we' 0
# word.lower=re 0
# word.lower=here 1
# word.lower=! 1
# word.lower=we' 0
# word.lower=re 0
# word.lower=here 1
# word.lower=! 1
# word.lower=donnes 1
# word.lower=-y 1
# word.lower=0 0
# word.lower=il 0
# word.lower=y 0
# word.lower=a 0
# word.lower=une 0
# word.lower=bombe 0
# word.lower=sur 0
# word.lower=gabrielle 0
# word.lower=0 0
# word.lower=0 0
# word.lower=walk 1
# word.lower=over 1
# word.lower=there 1
# word.lower=0 0
# word.lower=walk 1
# word.lower=over 1
# word.lower=there 1
# word.lower=! 1
# word.lower=move 0
# word.lower=! 0
# word.lower=ok 0
# word.lower=, 0
# word.lower=à 0
# word.lower=c 0
# word.lower=' 0
# word.lower=t' 0
# word.lower=heure 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=me 0
# word.lower=donnes 0
# word.lower=ma 0
# word.lower=fille 0
# word.lower=0 0
# word.lower=0 0
# word.lower=not 1
# word.lower=until 1
# word.lower=detective 1
# word.lower=ward 1
# word.lower=drops 1
# word.lower=his 1
# word.lower=gun 1
# word.lower=0 0
# word.lower=not 1
# word.lower=yet 1
# word.lower=, 1
# word.lower=david 1
# word.lower=0 0
# word.lower=not 1
# word.lower=yet 1
# word.lower=0 0
# word.lower=don' 0
# word.lower=t 0
# word.lower=you 1
# word.lower=push 1
# word.lower=your 1
# word.lower=luck 1
# word.lower=! 1
# word.lower=fuck 1
# word.lower=! 1
# word.lower=0 0
# word.lower=papa 1
# word.lower=! 1
# word.lower=0 0
# word.lower=martin 0
# word.lower=! 0
# word.lower=ok 0
# word.lower=, 0
# word.lower=ma 0
# word.lower=puce 0
# word.lower=0 0
# word.lower=ouvre 0
# word.lower=tes 0
# word.lower=yeux 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=peux 0
# word.lower=me 0
# word.lower=regarder 0
# word.lower=, 0
# word.lower=là 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=peux 0
# word.lower=me 0
# word.lower=regarder 0
# word.lower=0 0
# word.lower=enlève 0
# word.lower=- 0
# word.lower=moi 0
# word.lower=-la 0
# word.lower=, 0
# word.lower=papa 0
# word.lower=! 0
# word.lower=enlève 0
# word.lower=- 0
# word.lower=moi 0
# word.lower=-la 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=aime 0
# word.lower=pas 0
# word.lower=ça 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=aime 0
# word.lower=pas 0
# word.lower=ça 0
# word.lower=, 0
# word.lower=ça 0
# word.lower=me 0
# word.lower=fait 0
# word.lower=peur 0
# word.lower=! 0
# word.lower=je 0
# word.lower=sais 0
# word.lower=0 0
# word.lower=enlève 0
# word.lower=- 0
# word.lower=moi 0
# word.lower=-la 0
# word.lower=, 0
# word.lower=fais 0
# word.lower=quelque 0
# word.lower=chose 0
# word.lower=! 0
# word.lower=calme 0
# word.lower=-toi 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=peux 0
# word.lower=pas 0
# word.lower=bouger 0
# word.lower=comme 0
# word.lower=ça 0
# word.lower=0 0
# word.lower=allez 0
# word.lower=! 0
# word.lower=j 0
# word.lower=' 0
# word.lower=ai 0
# word.lower=besoin 0
# word.lower=de 0
# word.lower=toi 0
# word.lower=0 0
# word.lower=mais 0
# word.lower=essaie 0
# word.lower=quelque 0
# word.lower=chose 0
# word.lower=! 0
# word.lower=ça 0
# word.lower=me 0
# word.lower=fait 0
# word.lower=peur 0
# word.lower=! 0
# word.lower=on 0
# word.lower=fait 0
# word.lower=ça 0
# word.lower=ensemble 0
# word.lower=, 0
# word.lower=ok 0
# word.lower=? 0
# word.lower=0 0
# word.lower=don' 0
# word.lower=t 0
# word.lower=touch 1
# word.lower=it 1
# word.lower=. 1
# word.lower=it 1
# word.lower=might 1
# word.lower=be 1
# word.lower=booby 0
# word.lower=- 0
# word.lower=trapped 0
# word.lower=0 0
# word.lower=0 0
# word.lower=es 1
# word.lower=-tu 1
# word.lower=correct 1
# word.lower=? 1
# word.lower=0 0
# word.lower=yeah 1
# word.lower=0 0
# word.lower=here 1
# word.lower=and 1
# word.lower=here 1
# word.lower=0 0
# word.lower=it' 0
# word.lower=s 0
# word.lower=a 1
# word.lower=pretty 1
# word.lower=simple 1
# word.lower=device 1
# word.lower=0 0
# word.lower=bombmaking 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you 1
# word.lower=know 1
# word.lower=what 1
# word.lower=you' 0
# word.lower=re 0
# word.lower=talking 1
# word.lower=about 1
# word.lower=? 1
# word.lower=0 0
# word.lower=i 1
# word.lower=was 1
# word.lower=bomb 1
# word.lower=squad 1
# word.lower=before 1
# word.lower=jonathan 1
# word.lower=was 1
# word.lower=born 1
# word.lower=0 0
# word.lower=we' 0
# word.lower=re 0
# word.lower=gonna 1
# word.lower=have 1
# word.lower=to 1
# word.lower=pull 1
# word.lower=out 1
# word.lower=these 1
# word.lower=two 1
# word.lower=wires 1
# word.lower=simultaneously 1
# word.lower=0 0
# word.lower=you' 0
# word.lower=ll 0
# word.lower=have 1
# word.lower=to 1
# word.lower=do 1
# word.lower=it 1
# word.lower=. 1
# word.lower=you 1
# word.lower=need 1
# word.lower=two 1
# word.lower=hands 1
# word.lower=0 0
# word.lower=papa 1
# word.lower=0 0
# word.lower=ça 0
# word.lower=va 0
# word.lower=être 0
# word.lower=correct 0
# word.lower=0 0
# word.lower=ça 0
# word.lower=va 0
# word.lower=être 0
# word.lower=correct 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=0 0
# word.lower=orange 1
# word.lower=and 1
# word.lower=yellow 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you 1
# word.lower=sure 1
# word.lower=? 1
# word.lower=0 0
# word.lower=three 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=0 0
# word.lower=oui 0
# word.lower=, 0
# word.lower=oui 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=0 0
# word.lower=je 0
# word.lower=t 0
# word.lower=' 0
# word.lower=aime 0
# word.lower=0 0
# word.lower=0 0
# word.lower=pull 1
# word.lower=0 0
# word.lower=0 0
# word.lower=go 1
# word.lower=get 1
# word.lower=him 1
# word.lower=0 0
# word.lower=0 0
# word.lower=je 0
# word.lower=peux 0
# word.lower=pas 0
# word.lower=0 0
# word.lower=0 0
# word.lower=i' 0
# word.lower=ll 0
# word.lower=take 1
# word.lower=care 1
# word.lower=of 1
# word.lower=this 1
# word.lower=0 0
# word.lower=vas 1
# word.lower=-y 1
# word.lower=0 0
# word.lower=vas 0
# word.lower=-y 0
# word.lower=, 0
# word.lower=pogne 0
# word.lower=-le 0
# word.lower=puis 0
# word.lower=crisses 0
# word.lower=-y 0
# word.lower=une 0
# word.lower=volée 0
# word.lower=0 0
# word.lower=thank 1
# word.lower=you 1
# word.lower=0 0
# word.lower=mon 0
# word.lower=père 0
# word.lower=! 0
# word.lower=tiens 0
# word.lower=0 0
# word.lower=prends 0
# word.lower=ça 0
# word.lower=0 0
# word.lower=appelle 0
# word.lower=ta 0
# word.lower=mère 0
# word.lower=0 0
# word.lower=je 0
# word.lower=vais 0
# word.lower=aider 0
# word.lower=ton 0
# word.lower=papa 0
# word.lower=0 0
# word.lower=tu 0
# word.lower=restes 0
# word.lower=ici 0
# word.lower=, 0
# word.lower=ok 0
# word.lower=? 0
# word.lower=we' 0
# word.lower=ll 0
# word.lower=be 1
# word.lower=right 1
# word.lower=back 1
# word.lower=for 1
# word.lower=you 1
# word.lower=0 0
# word.lower=stay 1
# word.lower=here 1
# word.lower=0 0
# word.lower=0 0
# word.lower=dave 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=look 1
# word.lower=at 1
# word.lower=the 1
# word.lower=state 1
# word.lower=you' 0
# word.lower=re 0
# word.lower=in 1
# word.lower=0 0
# word.lower=t 0
# word.lower=' 0
# word.lower=aurais 0
# word.lower=fait 0
# word.lower=mieux 0
# word.lower=de 0
# word.lower=t 0
# word.lower=' 0
# word.lower=occuper 0
# word.lower=de 0
# word.lower=ta 0
# word.lower=fille 0
# word.lower=! 0
# word.lower=and 1
# word.lower=let 1
# word.lower=me 0
# word.lower=.. 0
# word.lower=0 0
# word.lower=take 1
# word.lower=care 1
# word.lower=of 1
# word.lower=buttman 1
# word.lower=0 0
# word.lower=toi 0
# word.lower=, 0
# word.lower=tu 0
# word.lower=parles 0
# word.lower=trop 0
# word.lower=0 0
# word.lower=0 0
# word.lower=no 1
# word.lower=! 1
# word.lower=don' 0
# word.lower=t 0
# word.lower=! 1
# word.lower=don' 0
# word.lower=t 0
# word.lower=do 1
# word.lower=it 0
# word.lower=. 0
# word.lower=it' 0
# word.lower=s 0
# word.lower=not 1
# word.lower=necessary 1
# word.lower=0 0
# word.lower=il 0
# word.lower=a 0
# word.lower=essayé 0
# word.lower=de 0
# word.lower=nous 0
# word.lower=tuer 0
# word.lower=puis 0
# word.lower=de 0
# word.lower=tuer 0
# word.lower=nos 0
# word.lower=enfants 0
# word.lower=! 0
# word.lower=il 0
# word.lower=va 0
# word.lower=revenir 0
# word.lower=! 0
# word.lower=0 0
# word.lower=all 1
# word.lower=good 1
# word.lower=things 1
# word.lower=come 1
# word.lower=to 1
# word.lower=those 1
# word.lower=who 1
# word.lower=wait 1
# word.lower=0 0
# word.lower=de 0
# word.lower=quoi 0
# word.lower=tu 0
# word.lower=parles 0
# word.lower=? 0
# word.lower=t 0
# word.lower=' 0
# word.lower=as 0
# word.lower=pas 0
# word.lower=fait 0
# word.lower=ça 0
# word.lower=? 0
# word.lower=tu 0
# word.lower=peux 0
# word.lower=faire 0
# word.lower=un 0
# word.lower=reset 0
# word.lower=là-dessus 0
# word.lower=? 0
# word.lower=0 0
# word.lower=i 1
# word.lower=prefer 1
# word.lower=to 1
# word.lower=think 1
# word.lower=of 1
# word.lower=it 1
# word.lower=as 1
# word.lower=recycling 1
# word.lower=0 0
# word.lower=t 0
# word.lower=' 0
# word.lower=es 0
# word.lower=sûr 0
# word.lower=ça 0
# word.lower=va 0
# word.lower=marcher 0
# word.lower=? 0
# word.lower=0 0
# word.lower=we' 0
# word.lower=ll 0
# word.lower=soon 0
# word.lower=see 0
# word.lower=0 0
# word.lower=man 1
# word.lower=, 1
# word.lower=can 1
# word.lower=that 1
# word.lower=guy 1
# word.lower=run 1
# word.lower=0 0
# word.lower=0 0
# word.lower=you 1
# word.lower=gotta 1
# word.lower=be 1
# word.lower=fucking 1
# word.lower=kidding 1
# word.lower=me 1
# word.lower=0 0
# word.lower=come 1
# word.lower=on 1
# word.lower=! 1
# word.lower=get 1
# word.lower=me 1
# word.lower=out 1
# word.lower=of 1
# word.lower=here 1
# word.lower=! 1
# word.lower=oh 1
# word.lower=shit 1
# word.lower=, 1
# word.lower=le 0
# word.lower=pingouin 0
# word.lower=! 0
# word.lower=gabrielle 0
# word.lower=? 0
# word.lower=0 0
# word.lower=in 1
# word.lower=conclusion 1
# word.lower=, 1
# word.lower=i 1
# word.lower=would 1
# word.lower=like 1
# word.lower=to 1
# word.lower=put 1
# word.lower=an 1
# word.lower=end 1
# word.lower=to 1
# word.lower=the 1
# word.lower=rumours 1
# word.lower=that 1
# word.lower=any 1
# word.lower=one 1
# word.lower=canadian 1
# word.lower=team 1
# word.lower=or 1
# word.lower=another 1
# word.lower=will 1
# word.lower=be 1
# word.lower=moving 1
# word.lower=to 1
# word.lower=the 1
# word.lower=u.s. 1
# word.lower=i 1
# word.lower=know 1
# word.lower=how 1
# word.lower=important 1
# word.lower=hockey 1
# word.lower=is 1
# word.lower=to 1
# word.lower=you 1
# word.lower=people 1
# word.lower=, 1
# word.lower=so 1
# word.lower=i 1
# word.lower=am 1
# word.lower=spearheading 1
# word.lower=a 1
# word.lower=rule 1
# word.lower=change 1
# word.lower=to 1
# word.lower=ensure 1
# word.lower=that 1
# word.lower=no 1
# word.lower=canadian 1
# word.lower=team 1
# word.lower=will 1
# word.lower=ever 1
# word.lower=have 1
# word.lower=to 1
# word.lower=move 1
# word.lower=from 1
# word.lower=its 1
# word.lower=home 1
# word.lower=city 1
# word.lower=! 1
# word.lower=no 1
# word.lower=more 0
# word.lower=questions 0
# word.lower=! 0
# word.lower=thank 1
# word.lower=you 1
# word.lower=0 0
# word.lower=no 1
# word.lower=more 0
# word.lower=questions 0
# word.lower=! 0

# %%
y_preda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-202-6c959e44dc87> in <module>()
# ----> 1 y_preda
#
# NameError: name 'y_preda' is not defined

# %%
# %%time

trainer = pycrfsuite.Trainer(verbose=False)

for xseq, yseq in zip(X_train, y_train):
    trainer.append(xseq, yseq)
# Out:
# CPU times: user 155 ms, sys: 3.11 ms, total: 158 ms
# Wall time: 157 ms

# %%
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    'max_iterations': 50,  # stop earlier

    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

# %%
# %%time
trainer.train('bon_cop_bad_cop.crfsuite')
# Out:
# CPU times: user 264 ms, sys: 8.29 ms, total: 272 ms
# Wall time: 277 ms

# %%
tagger = pycrfsuite.Tagger()
tagger.open('bon_cop_bad_cop.crfsuite')

# %% [markdown]
# ## Test CRF

# %%
# %%time
y_pred = [tagger.tag(xseq) for xseq in X_test]
# Out:
# CPU times: user 18.9 ms, sys: 688 µs, total: 19.6 ms
# Wall time: 19.2 ms

# %%
import itertools
y_test_flat = list(map(lambda x: int(x), itertools.chain.from_iterable(y_test)))
y_pred_flat = list(map(lambda x: int(x), itertools.chain.from_iterable(y_pred)))

# %% [markdown]
# - Sklearn no longer lets you pass sequences of sequences so I had to binarize the test and preds

# %% [markdown]
# ## Metrics

# %%
print(classification_report(y_test_flat, y_pred_flat))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.94      0.98      0.96      1984
#           1       0.96      0.88      0.92       960
#
# avg / total       0.95      0.95      0.95      2944

# %% [markdown]
# ### Accuracy

# %%
print(accuracy_score(y_test_flat, y_pred_flat))
# Out:
# 0.9473505434782609

# %% [markdown]
# ### F1

# %%
print(f1_score(y_test_flat, y_pred_flat))
# Out:
# 0.9155313351498637

# %% [markdown]
# ### Recall

# %%
print(recall_score(y_test_flat, y_pred_flat))
# Out:
# 0.875

# %% [markdown]
# ### Precision

# %%
print(precision_score(y_test_flat, y_pred_flat))
# Out:
# 0.96

# %%
from collections import Counter
info = tagger.info()

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(info.transitions).most_common(15))

print("\nTop unlikely transitions:")
print_transitions(Counter(info.transitions).most_common()[-15:])
# Out:
# Top likely transitions:
# 0      -> 0       1.492219
# 1      -> 1       1.089254
# 0      -> 1       -0.994067
# 1      -> 0       -1.316379
#
# Top unlikely transitions:
# 0      -> 0       1.492219
# 1      -> 1       1.089254
# 0      -> 1       -0.994067
# 1      -> 0       -1.316379

# %%
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-6s %s" % (weight, label, attr))    

print("Top positive:")
print_state_features(Counter(info.state_features).most_common(20))

print("\nTop negative:")
print_state_features(Counter(info.state_features).most_common()[-20:])
# Out:
# Top positive:
# 4.898535 0      word[-2:]=ue
# 4.180521 1      -1:word.lower=re
# 3.587072 1      word[-3:]=ing
# 3.355618 1      word.lower=we
# 3.315748 1      word.lower=you
# 3.031477 0      word[-3:]=ois
# 2.642684 1      word.lower=he
# 2.557469 0      +1:word.lower=t
# 2.401476 1      -1:word.lower=true
# 2.304134 0      word.lower=0
# 2.304134 0      word[-3:]=0
# 2.304134 0      word[-2:]=0
# 2.304134 0      word.isdigit=True
# 2.298590 1      -1:word.lower=s
# 2.296488 1      +1:word.lower=can'
# 2.292298 1      word[-3:]=ere
# 2.276572 1      -1:word.lower=ve
# 2.262047 1      word[-3:]=get
# 2.234258 1      -1:word.lower=ll
# 2.226562 0      +1:word.lower='
#
# Top negative:
# -0.835487 0      +1:word.lower=don'
# -0.852967 0      word[-2:]=ey
# -0.860526 1      +1:word.lower=i
# -0.871512 1      word[-3:]=ais
# -0.897704 0      word[-2:]=an
# -0.970256 0      word.lower=no
# -1.034177 0      +1:word.lower=he'
# -1.039045 1      word.lower=way
# -1.056343 0      word.lower=it
# -1.065781 0      +1:word.lower=i'
# -1.076716 1      +1:word.lower=..
# -1.124843 0      word[-2:]=ay
# -1.177364 0      word[-3:]=ers
# -1.221525 0      +1:word.lower=you'
# -1.255928 0      +1:word.lower=it'
# -1.266875 0      -1:word.lower=up
# -1.574227 0      -1:word.lower=m
# -1.590538 1      +1:word.lower=.
# -2.210112 0      -1:word.lower=t
# -2.298590 0      -1:word.lower=s
