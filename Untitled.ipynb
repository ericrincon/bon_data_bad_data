# %%
import pysubs2
import spacy
import pandas as pd
import os.path

from spacy.tokens import Doc # to create empty Doc
from spacy.vocab import Vocab # to create empty Vocab

# %%
nlp_en = spacy.load('en')
nlp_fr = spacy.load('fr')

# %%
def load_data():
    if os.path.exists('bcbc_fr_parsed') and\
        os.path.exists('bcbc_en_parsed.bin'):
        return Doc(Vocab()).from_disk('bcbc_fr_parsed.bin'), \
                    Doc(Vocab()).from_disk('bcbc_en_parsed.bin')
    else:  
        subs_french = pysubs2.load('bon_french/Bon.Cop.Bad.Cop.2006.720p.BluRay.H264.AAC-RARBG.srt',
                            encoding='iso-8859-1')
        subs_eng = pysubs2.load('bon_eng/Bon.Cop.Bad.Cop.2006.720p.BluRay.x264-.YTS.AG.srt')
        french_subs = " ".join([line.text for line in subs_french])
        french_parsed = nlp_fr(french_subs)

        eng_subs = " ".join([line.text for line in subs_eng])
        eng_parsed = nlp_en(eng_subs)

        french_parsed.to_disk('bcbc_fr_parsed.bin')
        eng_parsed.to_disk('bcbc_en_parsed.bin')

        return french_parsed, eng_parsed

# %%
french_parsed, eng_parsed = load_data()

# %%
[x.tag_ for x in french_parsed]
# Out:
# ['PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'ADV___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PRON__PronType=Rel',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Number=Sing',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'DET__Gender=Masc|Number=Sing',
#  'ADV___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'DET__Number=Sing|Poss=Yes',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'DET__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'DET__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'AUX__VerbForm=Inf',
#  'NOUN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PRON__PronType=Rel',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'PRON__Number=Plur|Person=2',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'SCONJ___',
#  'ADV___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'VERB__Gender=Fem|Number=Plur|Tense=Past|VerbForm=Part',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADJ__Number=Plur',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'PROPN__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Tense=Past|VerbForm=Part',
#  'PRON__PronType=Int',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Fem|Number=Plur',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'AUX__VerbForm=Inf',
#  'AUX__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__PronType=Rel',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'SCONJ___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'PRON__Number=Sing|PronType=Rel',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'VERB__VerbForm=Inf',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Person=3|Reflex=Yes',
#  'VERB__VerbForm=Inf',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'SCONJ___',
#  'NOUN__Gender=Masc',
#  'ADV___',
#  'VERB__Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'NOUN___',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'ADV',
#  'VERB',
#  'PRON__Number=Sing|Person=3',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PROPN___',
#  'PROPN___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADJ__Number=Sing',
#  'ADJ___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'ADP___',
#  'PROPN___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Number=Plur',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Sing|PronType=Art',
#  'NOUN__Number=Sing',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Fem|Number=Sing',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN___',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin',
#  'ADV___',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADV___',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Plur|Person=2',
#  'VERB__Mood=Ind|Number=Plur|Person=2|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'VERB__Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Imp|VerbForm=Fin',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Masc|Number=Sing|PronType=Dem',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'DET__Definite=Def|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'DET__Gender=Fem|Number=Sing|PronType=Dem',
#  'ADJ__Gender=Fem|Number=Sing',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADP___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NUM__NumType=Card',
#  'PUNCT___',
#  'NUM__NumType=Card',
#  'ADP___',
#  'PROPN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PRON__Number=Sing|PronType=Rel',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'DET__Gender=Fem|Number=Sing|Poss=Yes',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Masc',
#  'ADV__Polarity=Neg',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'DET__Definite=Ind|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'ADJ__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'NOUN__Gender=Fem|Number=Sing',
#  'ADP___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADP___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PROPN___',
#  'X___',
#  'PUNCT___',
#  'ADV__Polarity=Neg',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADV___',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'ADJ__Gender=Fem|Number=Sing',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Dem',
#  'ADV__Polarity=Neg',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'SCONJ___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'ADV___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__PronType=Rel',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADP___',
#  'PROPN___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN___',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1|PronType=Prs',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADV___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ___',
#  'ADP___',
#  'DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'CCONJ___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'ADP___',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PRON__Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADJ__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'PROPN___',
#  'PUNCT___',
#  'CCONJ___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'PRON__Number=Sing|Person=3',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Plur|Person=3',
#  'PRON__Number=Sing|Person=1',
#  'AUX__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin',
#  'VERB__Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'ADJ__Gender=Fem|Number=Plur',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'ADV___',
#  'ADP___',
#  'VERB__VerbForm=Inf',
#  'ADV___',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'PRON__Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'PROPN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=3',
#  'AUX__Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'ADJ__Number=Sing',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADJ__Gender=Masc',
#  'NOUN__Gender=Fem|Number=Plur',
#  'VERB__VerbForm=Inf',
#  'DET__Number=Sing',
#  'NOUN__Number=Sing',
#  'PUNCT___',
#  'ADV___',
#  'ADP___',
#  'ADV___',
#  'PUNCT___',
#  'NOUN__Gender=Fem|Number=Sing',
#  'CCONJ___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'PRON__Number=Sing|Person=1',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin',
#  'ADV___',
#  'PUNCT___',
#  'ADP___',
#  'VERB__VerbForm=Inf',
#  'DET__Definite=Def|Number=Plur|PronType=Art',
#  'NOUN__Gender=Masc|Number=Plur',
#  'ADJ__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'VERB__VerbForm=Inf',
#  'ADJ__Gender=Fem|Number=Plur',
#  'NOUN__Gender=Fem|Number=Plur',
#  'PUNCT___',
#  'PUNCT___',
#  'ADP___',
#  'ADV___',
#  'ADV___',
#  'PUNCT___',
#  'ADV__PronType=Int',
#  'VERB__Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin',
#  'PUNCT___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Number=Sing|Person=1',
#  'ADV__Polarity=Neg',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'ADV__Polarity=Neg',
#  'ADP___',
#  'PRON__Gender=Masc|Number=Sing|Person=3|PronType=Prs',
#  'DET__Definite=Ind|Gender=Fem|Number=Sing|PronType=Art',
#  'NOUN__Gender=Masc|Number=Sing',
#  'ADJ__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PROPN__Number=Plur',
#  'PUNCT___',
#  'ADJ__Gender=Masc|Number=Sing',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NUM__NumType=Card',
#  'NOUN__Gender=Masc|Number=Plur',
#  'PUNCT___',
#  'CCONJ___',
#  'NOUN__Gender=Masc',
#  'NOUN___',
#  'DET__Number=Sing|Poss=Yes',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PRON__Number=Sing|Person=1',
#  'NOUN__Gender=Fem|Number=Sing',
#  'PUNCT___',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  'VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#  'NOUN__Gender=Fem|Number=Sing',
#  'VERB__Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part',
#  'ADP___',
#  'NOUN__Gender=Masc|Number=Sing',
#  'PUNCT___',
#  'PRON__Gender=Masc|Number=Sing|Person=3',
#  '
# 13488  13489             !  Montréal, Québec  Harry Buttman           English
# 13489  13490         Thank  Montréal, Québec  Harry Buttman           English
# 13490  13491           you  Montréal, Québec  Harry Buttman           English
# 13491  13492             0  Montréal, Québec  Harry Buttman           English
# 13492  13493            No  Montréal, Québec  Harry Buttman           English
# 13493  13494          more  Montréal, Québec  Harry Buttman           English
# 13494  13495     questions  Montréal, Québec  Harry Buttman           English
# 13495  13496             !  Montréal, Québec  Harry Buttman           English
# 13496  13497  Sous-titrage              None           None              None
# 13497  13498           DVD              None           None              None
# 13498  13499             :              None           None              None
# 13499  13500          CNST              None           None              None
# 13500  13501             ,              None           None              None
# 13501  13502      Montréal              None           None              None
#
#             Token.1      Tag1   Tag2       Tag
# 0                On        Fr    NaN        Fr
# 1             passe        Fr    NaN        Fr
# 2                 à     Punct    NaN     Punct
# 3                un        Fr    NaN        Fr
# 4             autre        Fr    NaN        Fr
# 5             appel        Fr    NaN        Fr
# 6                et        Fr    NaN        Fr
# 7                on        Fr    NaN        Fr
# 8             parle        Fr    NaN        Fr
# 9                 à     Punct    NaN     Punct
# 10          Patrick  NamedEnt    NaN  NamedEnt
# 11                0     Punct    NaN     Punct
# 12          Patrick  NamedEnt    NaN  NamedEnt
# 13              NaN       NaN  Punct     Punct
# 14          bonsoir        Fr    NaN        Fr
# 15                0     Punct    NaN     Punct
# 16            Salut        Fr    NaN        Fr
# 17              NaN       NaN  Punct     Punct
# 18              Ron  NamedEnt    NaN  NamedEnt
# 19              NaN       NaN  Punct     Punct
# 20          comment        Fr    NaN        Fr
# 21               ça        Fr    NaN        Fr
# 22               va        Fr    NaN        Fr
# 23                ?     Punct    NaN     Punct
# 24               Ah        Fr    NaN        Fr
# 25              NaN       NaN  Punct     Punct
# 26              pas        Fr    NaN        Fr
# 27             pire        Fr    NaN        Fr
# 28              NaN       NaN  Punct     Punct
# 29              pas        Fr    NaN        Fr
# ...             ...       ...    ...       ...
# 13472            no       Eng    NaN       Eng
# 13473      Canadian        Fr    NaN        Fr
# 13474          team       Eng    NaN       Eng
# 13475          will       Eng    NaN       Eng
# 13476          ever       Eng    NaN       Eng
# 13477          have       Eng    NaN       Eng
# 13478            to       Eng    NaN       Eng
# 13479          move       Eng    NaN       Eng
# 13480          from       Eng    NaN       Eng
# 13481           its       Eng    NaN       Eng
# 13482          home       Eng    NaN       Eng
# 13483          city       Eng    NaN       Eng
# 13484             !     Punct    NaN     Punct
# 13485            No       Eng    NaN       Eng
# 13486          more       Eng    NaN       Eng
# 13487     questions       Eng    NaN       Eng
# 13488             !     Punct    NaN     Punct
# 13489         Thank       Eng    NaN       Eng
# 13490           you       Eng    NaN       Eng
# 13491             0     Punct    NaN     Punct
# 13492            No       Eng    NaN       Eng
# 13493          more       Eng    NaN       Eng
# 13494     questions        Fr    NaN        Fr
# 13495             !     Punct    NaN     Punct
# 13496  Sous-titrage        Fr    NaN        Fr
# 13497           DVD        Fr    NaN        Fr
# 13498             :     Punct    NaN     Punct
# 13499          CNST        Fr    NaN        Fr
# 13500           NaN       NaN  Punct     Punct
# 13501      Montréal  NamedEnt    NaN  NamedEnt
#
# [13502 rows x 9 columns]
