# %%
import pysubs2
import spacy
import pandas as pd
import numpy as np
import os.path
from collections import Counter

from spacy.tokens import Doc # to create empty Doc
from spacy.vocab import Vocab # to create empty Vocab

# %%
nlp_en = spacy.load('en')
nlp_fr = spacy.load('fr')

# %%
def load_data():
    if os.path.exists('bcbc_fr_parsed') and \
        os.path.exists('bcbc_en_parsed.bin'):
        return Doc(Vocab()).from_disk('bcbc_fr_parsed.bin'), \
                    Doc(Vocab()).from_disk('bcbc_en_parsed.bin')
    else:  
        subs_french = pysubs2.load('bon_french/Bon.Cop.Bad.Cop.2006.720p.BluRay.H264.AAC-RARBG.srt',
                            encoding='iso-8859-1')
        subs_eng = pysubs2.load('bon_eng/Bon.Cop.Bad.Cop.2006.720p.BluRay.x264-.YTS.AG.srt')
        french_subs = " ".join(line.text for line in subs_french)
        french_parsed = nlp_fr(french_subs)

        eng_subs = " ".join(line.text for line in subs_eng)
        eng_parsed = nlp_en(eng_subs)

        french_parsed.to_disk('bcbc_fr_parsed.bin')
        eng_parsed.to_disk('bcbc_en_parsed.bin')

        return subs_french, french_parsed, subs_eng, eng_parsed

# %%
french_subs, french_parsed, eng_subs, eng_parsed = load_data()

# %%
[x.tag_ for x in french_parsed]
# TODO: Get tokens from each script and align them somehow
#       Maybe they don't have to be aligned, just use indexing to get
#       "corresponding" token from other script
#       Keep track of current script and switch according to prob_matrix 
#       below, choose one monolingual script for starters
# Out:
# ['- On passe à un autre appel\\Net on parle à Patrick.',
#  'Patrick, bonsoir.\\N- Salut, Ron, comment ça va?',
#  '- Ah, pas pire, pas pire,\\Npas pire, pas pire... Pas!',
#  "- Que c'est tu penses de ça, toi,",
#  'la rumeur que Toronto\\Nserait vendu à Houston?',
#  '- Toronto à Houston?\\NOuais, non, non! Non, non, non, non!',
#  "La vraie rumeur,\\Nc'est pas ça du tout, Patrick.",
#  '- Bien, moi, mon beau-frère,\\Nil était considéré...',
#  '- Beau-frère...',
#  'Beau-frère, cousin, belle-soeur,',
#  'le chauffeur de taxi,',
#  'le barman, euh...',
#  'Mononcle, fils à mononcle,\\Nblonde du fils du beau-père,',
#  'ça a pas rapport, pas deux secondes!',
#  '... Il y a une équipe canadienne,',
#  'ça peut être Vancouver,\\Nça peut être Calgary,',
#  'ça peut être Edmonton,\\NToronto ou Montréal',
#  'qui peut déménager,\\Nça, je vous le donne.',
#  '- Quand même, depuis le lock-out...',
#  '- Le lock-out! hâllo! Lock-out!\\NIl est où, le lock-out?',
#  'Quoi, le lock-out? Lock-out?',
#  '- Buttman, avec\\Nses affaires cheap américaines,',
#  'comme les cheerleaders,\\Nles mascottes...',
#  '- Les cheerleaders\\Navec les pompons,',
#  "c'est pas pire, je peux vivre\\Navec ça. Mais les mascottes!",
#  'Pas sûr, les mascottes,\\Navec la queue, le poil...',
#  'Je suis pas certain des mascottes,\\Npas deux secondes...',
#  'Mais savez-vous quoi?\\N- Non.',
#  '- Savez-vous quoi, Patrick?\\N- Non.',
#  '- Patrick, savez-vous quoi?',
#  'Avec le nouveau système,\\Nles Patriotes de Montréal',
#  'rencontrent Toronto en finale.',
#  "... bye, Patrick.\\NMerci d'avoir appelé.",
#  "- Que c'est qui se passe?",
#  'Pourquoi je suis attaché, moi?',
#  "Que c'est que je fais ici, moi, là?",
#  "Que c'est que j'ai fait, moi?",
#  "- C'est ça, le problème,",
#  "t'as rien fait.",
#  '- Ah...',
#  "J'ai essayé de t'aider, tu sais.",
#  'Tu le sais, ça. Hein? Hein?',
#  'Hein?',
#  'Tu le sais.',
#  'Moi, je voulais pas\\Nte laisser tomber.',
#  "Regarde, détache-moi,\\Non va s'arranger.",
#  'Hein? Détache-moi!',
#  'Argh!',
#  'Ah! Hostie... Regarde...',
#  "On va s'aider, hein?",
#  "Tu le sais, t'as toujours été\\Nun petit frère pour moi, hein?",
#  '- Chut! Chut! Chut!\\N- HEIN?',
#  'Ah...',
#  "Qu'est-ce qu'il y a, là?",
#  "T'es où, là?",
#  '- Chut! Chut! Chut!',
#  'La game commence.\\N- Ah...',
#  'Ah!',
#  '... à ce match de grande finale',
#  'entre les Loyalists de Toronto',
#  'et les Patriotes de Montréal.',
#  "L'arbitre est prêt pour la mise\\Nen jeu, voilà, ça y est...",
#  '- Toronto est toujours en forme',
#  'et les arbitres "eur-o-péens"\\Nsont toujours perdus.',
#  "C'est pas mieux à Montréal.",
#  'Vous rappelez-vous\\Nquand Montréal avait des "Frenchies"',
#  'qui savaient compter?\\NCe temps-là est bien fini!',
#  "- Merci, Tom, pour ce commentaire\\Ninspirant pour l'esprit national.",
#  'Bravo! Tu réussis à dénigrer\\Nles "Frenchies"',
#  'et les "eur-o-péens"\\Ndans la même phrase.',
#  'Quel beau pays\\Nen cette belle journée de mai...',
#  '- Bonjour, toi!',
#  '...qui risque de chauffer\\Ncomme la tête de Tom Berry.',
#  'Il est 7: 30 à Toronto.',
#  '- Y a rien!',
#  '- Où vas-tu?',
#  '- Dans ma chambre.',
#  "- Tu n'as pas faim\\Npour de bonnes céréales?",
#  "- J'ai pas envie de manger\\Ndu carton déchiqueté.",
#  "- Comment c'était hier, ton truc de DJ?\\N- C'était bien.",
#  "- Tu t'es amusé?\\N- Han, han.",
#  '- Salut, les gars!',
#  '- Je devrai peut-être travailler\\Ntoute la nuit; ta tante reste ici.',
#  '- Tape là-dedans.',
#  "- J'espère que ça ne durera pas.",
#  "J'espère que moi aussi,\\Nj'aurai un travail DJ.",
#  '- Un quoi?\\N- Un travail DJ.',
#  '- Oh, Seigneur!',
#  '- Un travail "De Jour".\\NVous saisissez?',
#  '- Ouais.',
#  '- Où vas-tu?\\NRaconte-moi un truc amusant.',
#  '- Hier soir,\\Nje mettais de la musique...',
#  '- Oui.\\N- Et tout le monde hallucinait.',
#  "Ça dansait sur les tables.\\N- C'est vrai?",
#  '- Après, il y avait un autre DJ.',
#  "Mais personne ne l'aimait,\\Nalors ils m'ont redemandé.",
#  '- Super! Toutes les filles\\Ndevaient te tourner autour.',
#  '- Oui... Il y avait une rouquine.',
#  '- Une rouquine?\\N- Oui.',
#  "- C'était une simple question.",
#  '- Tu sais quoi?\\NAllons déjeuner quelque part.',
#  "Loin d'ici, toi et moi.\\NTu me raconteras tout.",
#  'Sans oublier les détails croustillants.',
#  'Va prendre tes affaires.',
#  '- À plus tard.',
#  'Comment fais-tu?',
#  "Je n'arrive pas à lui tirer\\Nune phrase complète.",
#  '- Voyons, grand frère.',
#  'Il a 15 ans.',
#  "Et tu es son père.\\N- J'imagine.",
#  '- Il fait présentement\\N22 degrés à Montréal.',
#  'Hé, hé hé! Avez-vous vu\\Nle match hier soir?',
#  'Toronto lâchera pas le morceau,\\Nça fait que lâchez pas, les gars!',
#  'Ça sent la coupe!\\NOn enchaîne...',
#  "- Ah... Ouh! Ah, t'es là? Wow.",
#  "T'es bien fin.",
#  '- Bon matin.',
#  '- Merci.\\N- Tout le monde.',
#  "- Ha, ha, t'es con!",
#  '- Papa!',
#  "- Ah! Ma petite fille d'amour!",
#  "- C'est un méchant qui t'a fait ça?",
#  "- Oui, j'ai rencontré quelqu'un",
#  'qui avait la tête\\Nplus dure que maman.',
#  '- Ha! Ha.... Très drôle.',
#  'Très, très, très drôle.',
#  'hâllo, ma cocotte.\\NAs-tu bien dormi?',
#  '- Oui.',
#  'Wow, du pain doré?',
#  'Merci, papa.',
#  '- Ça me fait plaisir.',
#  "- Papa, j'aurais quelque chose\\Nà te demander.",
#  "- Ah, Oh.\\NQue c'est qu'il y a, ma puce?",
#  '- Est-ce que je pourrais\\Nme faire percer le nombril?',
#  '- Hum!\\N- Pardon?',
#  '- Le nombril.',
#  'Est-ce que je pourrais\\Nme faire percer le nombril?',
#  "- Qu'est-ce que ta mère dit de ça?",
#  "- Tu peux être sûr\\Nqu'elle s'est pas essayée avec moi.",
#  '- Regarde, je vais penser à ça,\\Npuis je te reviens là-dessus.',
#  "- T'es pas cool!",
#  '- Gabrielle, veux-tu aller\\Nen haut chez moi chercher du lait?',
#  "- J'avais dit à mes amis\\Nque t'étais le père le plus cool.",
#  '- Tien oui!',
#  '- Ça marche pas,\\Nton affaire de cool.',
#  'Oh, envoye!\\NMerci, bye-bye...',
#  '- Tu peux te faire coudre\\Nà chaque semaine,',
#  'mais je peux pas me faire\\Npercer le nombril?',
#  "- Gabrielle, j'ai pas dit non.\\NJe vais en parler avec ta mère",
#  "puis elle va me dire\\Nce qu'on a décidé.",
#  "- T'es même pas drôle.",
#  '- Hé, va chercher du lait\\Nparce que moi, je vais...',
#  '- Oh! Envoye!\\N- Oh! Oh!',
#  '- Percer le nombril!',
#  "Qu'est-ce qu'il y a?",
#  '- Ah... Mais non.',
#  "C'est juste que si t'étais\\Ncapable d'être comme ça",
#  'plus que 10 minutes\\Non serait peut-être encore mariés.',
#  '- Come on.',
#  "C'est pas si pire que ça.",
#  'Il y en a qui ont même pas ça.',
#  "- Non, sauf qu'entre\\Nchaque beau 10 minutes,",
#  'bien il y a la job,',
#  'les filles,',
#  'la job, les chums, le hockey,',
#  'Le téléphone.',
#  '- Bouchard.',
#  'Oui.',
#  "Ah, come on,\\Nc'est ma journée off, là!",
#  '- Et voilà!',
#  "- C'est correct,\\Nc'est correct, j'arrive.",
#  "Il faut que j'y aille.",
#  "Mais c'est intéressant,\\Ncette conversation-là,",
#  'on continuera ça\\Nun moment donné.',
#  "- Hé! Pff! Quand Gabrielle\\Nsera à l'université!",
#  '- Ça presse-tu tant que ça?',
#  '- Oublie pas le spectacle de ta fille.',
#  '- Hé, franchement.',
#  "Penses-tu que j'oublierais\\Nune affaire de même?",
#  'Suzie?',
#  '- Hein?',
#  "- C'est quand?\\N- C'est à 4 h 00.",
#  'Hé!',
#  'Comment tu veux\\Nque je me trouve un chum?',
#  "C'est déjà dur avec un enfant,\\Nimagine avec deux.",
#  '- Tien voyons donc, dis pas ça.',
#  "Tu vas t'en retrouver un.",
#  "T'as encore des seins magnifiques.",
#  '- Hé, commence pas, toi!\\NEnvoye! Va jouer à la police!',
#  'Va rejoindre tes petits amis.',
#  '- Hostie de câlice de tabarnak!',
#  "C'est qui qui s'est\\Noccupé du barrage?",
#  'Deux heures pour me rendre\\Nsur ma scène de crime!',
#  '- Mais là, Dave, come on...',
#  "- Pour toi, aujourd'hui,\\Nc'est détective Dave.",
#  'Martin Ward.',
#  'David Bouchard.',
#  '- Enchanté.',
#  'Enchanté!',
#  'Hé, on est tombés sur un gars\\Nqui peut parler le "française"!',
#  "Je suppose que c'est la victime.",
#  '- On ne peut pas encore\\Nle considérer comme une victime.',
#  'Mais on peut affirmer\\Nque la nuit a été rude pour lui.',
#  "Il n'y a pas beaucoup de sang.",
#  "- En tout cas, ça m'a fait plaisir.",
#  'Bonne chance, les boys!',
#  '- Où allez-vous comme ça?',
#  '- Chez nous.',
#  "Il m'apparaît évident\\Nque c'est votre affaire.",
#  "- Quoi? Il est évident\\Nque c'est votre affaire.",
#  '- Comment pouvez-vous dire ça?',
#  'Ses pieds sont de votre côté.',
#  "- C'est vrai, et sa tête est du vôtre.\\NAlors?",
#  '- Quand on joue au football,\\Nau tennis ou à un autre sport,',
#  "lorsque le pied traverse la ligne,\\Non est à l'extérieur.",
#  "Oh, les boys, on n'a plus rien\\Nà faire ici, on décrisse.",
#  "- Puis-je vous rappeler\\Nqu'aux 100 mètres,",
#  "c'est la tête et la poitrine\\Nqui déchirent le ruban.",
#  "Dans les courses de chevaux,\\Nc'est le nez qui compte.",
#  "Comme vous pouvez le constater,\\Nc'était un vrai Québécois.",
#  "- Ai-je besoin d'un passeport?\\N- Son coeur est au Québec.",
#  "- Il a l'Ontario dans le cul, aussi.",
#  '- Pardon?',
#  "- J'ai dit que son cul\\Nvous appartenait.",
#  '- Oh.',
#  "On va s'en occuper, alors.",
#  'Apportez-moi une échelle.',
#  '- Une échelle!\\N- Une échelle! Go!',
#  '- Wô!',
#  'Ne le bougez pas.',
#  '- Il est encastré dans la pancarte.',
#  '- Peu importe, finissons-en.',
#  "- Qu'est-ce que c'est?",
#  '- Faites attention, ne bougez rien.',
#  '- Hé, là, là! Oh!',
#  'Ah, shit...',
#  '- Idiot!',
#  'Ne touche pas!',
#  '- AAAAH!',
#  '- Bonjour.',
#  '- Joli col roulé.\\NTout à fait ton style.',
#  "Que c'est qu'il câlice ici,\\Nla tête carrée?",
#  '- David, tu connais Martin?',
#  "Je te présente Brian MacDuff,\\Nle chef de la Sûreté de l'Ontario.",
#  '- Enchanté.',
#  "- C'est ça, oui.",
#  'Je peux savoir\\Nce que je fais encore ici',
#  'à cette heure-là, à matin?',
#  '- Voulez-vous parler, Brian?',
#  "- C'est votre juridiction.",
#  "- Non, j'insiste.",
#  'Oh.',
#  'On sait que la victime\\Nest de Montréal.',
#  '- On sait...',
#  '... que la victime...',
#  '... est de Montréal.',
#  '- Mais on ne sait pas encore',
#  "si c'est un meurtre,\\Net, si c'est le cas,",
#  "d'où vient le meurtrier.",
#  "- On n'est pas certains encore",
#  "que c'est un meurtre,",
#  "et si c'est le... le cas,",
#  "d'où vient... le meurtrier.",
#  '- Le capitaine Leboeuf\\Net moi pensions',
#  "que c'était une belle opportunité...",
#  '- Et on pensait,\\Nle capitaine Leboeuf et moi,',
#  "que c'était une belle...",
#  'opportunité de... de...',
#  '- Oh, ça va, chef.',
#  "Je comprends l'anglais.",
#  '- Ah bien, ouais, Oh.',
#  "C'est correct...",
#  'David...',
#  "peut l'anglais.",
#  "Peut l'anglais.",
#  '- He can...\\N- Oh!',
#  'Oh!\\N- Yes!',
#  "- D'accord, allez-y.\\N- D'accord, j'y vais, j'y vais.",
#  'Nous pensions que\\Nc\'était une belle "otorpun..."',
#  '- Opportunité.',
#  "- Que c'était une belle opportunité...",
#  'pour être...',
#  '- Vous pouvez parler français,\\Ncapitaine.',
#  '- Mais ciboire!',
#  '- Tu parles français, toi?',
#  '- Non, je parle pas français.',
#  'Je me suis fait installer\\Nun gadget au cerveau.',
#  "Et je vois des sous-titres\\Nsur les gens lorsqu'ils parlent.",
#  'Oui, je parle français.',
#  "J'étais en français enrichi\\Nà Upper Canada College.",
#  '- Upper quoi?',
#  "- Et j'ai aussi vécu une année à Paris.",
#  "- Ah, Oh. C'est pour ça\\Nqu'il est chiant de même.",
#  '- Hé!',
#  "D'accord!",
#  'On veut montrer à la GRC',
#  "qu'ils ne peuvent pas avoir\\Ntout le gâteau.",
#  '- Ha! Non!',
#  'Oh.',
#  '- Alors, si nous pouvons collaborer,',
#  'ce serait très bon pour notre image',
#  "et pour notre budget de l'an prochain.",
#  "- Ha! Yes! Yes! Fait que\\Njusqu'à nouvel ordre, vous êtes...",
#  'partners.',
#  "- C'est une blague?\\N- Hé, c'est une joke, ça?",
#  '- Hé, écoute-moi bien, toi!',
#  "Si je me fie à ce que Sylvain\\Nm'a raconté hier soir,",
#  "si j'étais à ta place,\\Nje m'inquiéterais plus",
#  "d'une suspension\\Nque d'un autre partner, Oh?",
#  "Fait que, que c'est qu'il va faire,\\NDavid?",
#  'Il va pogner son trou, puis il va me\\Nrégler ce dossier-là au plus sacrant.',
#  "- Je sors d'une enquête difficile.",
#  'Je ne peux pas travailler\\Navec ce clown.',
#  "- Tu n'as pas le choix.\\NTu veux un travail de bureau, non?",
#  '- Envoye!',
#  'Envoye!',
#  '- Grossbut.',
#  '- Maître Grossbut?\\NMaître Brisset est mort.',
#  '- Pardon?',
#  "- Il a été retrouvé en Ontario.\\N- C'est arrivé quand?",
#  "- On n'a pas l'information,\\Nla police commence l'enquête.",
#  "- Voyons, c'est pas possible!",
#  "Tout le monde l'aimait, Brisset!",
#  '- Il avait des problèmes\\Navec des clients?',
#  '- Non, non, je vois pas.',
#  'Je suis pas au courant\\Nde tous ses dossiers,',
#  "mais s'il avait eu\\Ndes problèmes avec un client,",
#  "il m'en aurait parlé.",
#  '- Sûrement. Vous le connaissiez\\Ndepuis plusieurs années?',
#  '- Oui, je le connaissais\\Ndepuis longtemps,',
#  'mais on a commencé\\Nà travailler ensemble',
#  'sur le dossier du Fleur de Lys.',
#  "- C'est vrai?\\N- On s'est jamais lâchés depuis.",
#  'Est-ce que la famille a été avisée?',
#  "- J'en ai aucune idée.\\NVous les connaissez bien?",
#  '- Oui. Écoutez, si je peux faire\\Nquoi que ce soit...',
#  '- Laissez-moi vérifier...\\N- Oui. Merci!',
#  '- Salut, Michel.',
#  "Je t'attendais.\\N- Oh!",
#  '- Hi, ça a... ça a fessé.',
#  '- Benoit Brisset, 46 ans.',
#  'Partenaire depuis peu',
#  'chez Grossbut-Canuelsberg-\\NTiernyskovitch-Chun et Brisset',
#  "Divorcé, pas d'enfant.",
#  'Trois condos:\\Nun à Boca Raton, un à Nice.',
#  'Travaille 75 heures par semaine,\\Nce qui est beaucoup pour Montréal.',
#  'Aucun lien connu avec la mafia.\\NMembre du club de golf Mirage.',
#  'Il conduit un Cherokee.\\NVoulez-vous savoir autre chose?',
#  '- Oui, il est-tu circoncis?',
#  '- Oui.',
#  '- Martin, Jeff; Jeff, Martin Ward,',
#  "mon homologue de l'OPP.",
#  '- Enchanté.\\N- Salut.',
#  "- Je sais qu'à première vue,\\Nil a l'air d'un comptable homosexuel,",
#  'mais fie-toi pas aux apparences,\\Nil est pas comptable.',
#  "- D'accord.",
#  '- Pouvez-vous évaluer...\\N- À quelle hauteur il est tombé?',
#  "Ça dépend de la vitesse\\Nde l'hélicoptère.",
#  "- Wô, qui a parlé d'hélicoptère?",
#  "- Attends un peu, c'est moi.",
#  "Je viens d'en parler. Ça peut pas\\Nêtre un avion, c'est trop vite,",
#  'il aurait coupé en deux sans vous.',
#  "Un parachute pas ouvert,\\Nil l'aurait encore sur le dos.",
#  "Personne se pitche\\Nen bas d'un deltaplane.",
#  "C'est trop compliqué\\Navec les straps puis tout.",
#  'Le Festival des montgolfières\\Nest pas commencé,',
#  "puis si c'est une cigogne,\\Nelle est 46 ans en retard.",
#  "D'après moi, hélicoptère.",
#  'Pour répondre à la question,',
#  'au plus haut, 80 mètres.',
#  "Ça fait 236 pieds, 4 pouces,\\N7 huitièmes. C'est pas exact.",
#  'Un corps inerte en chute libre\\Nfait 30 mètres à la seconde.',
#  "Selon les dégâts, ça, c'est minimum\\N25 mètres. Maximum 80.",
#  "J'ai le feeling\\Nque ça peut pas être 60 mètres.",
#  "Sinon, sa chute aurait été\\Nd'exactement 2 secondes.",
#  "C'est un chiffre trop rond,\\Nje le sens pas, ça se peut pas.",
#  "Il y a rien de si précis dans la vie.\\ND'après moi, 80 mètres.",
#  "- Et ça, qu'est-ce que c'est?",
#  '- Comment tu dis ça\\Ntatou en anglais?',
#  '- Tattoo.\\N- TattoOh',
#  'Un tattoo. Spécial, hein?',
#  'Parce qu\'il y a 2 "T" et 2 "O",',
#  'mais c\'est le "A" que vous\\Ndites longtemps. Taaaattoo.',
#  '- Pourquoi il y a du sang?',
#  "- S'il est tombé de 200 pieds,\\Nça a breaké sec en hostie.",
#  'Mais un tatou, Jeff, ça peut prendre\\Nune dizaine de jours à cicatriser?',
#  "- Mais c'est bien plus frais que ça.\\NQuelques heures à peine.",
#  'Il a pas commencé\\Nà cicatriser pantoute.',
#  '"Pantutti" pour vous.',
#  '- Mais pourquoi...',
#  '- ... cette partie du tatou saigne pas?',
#  '- Le gars peut...',
#  "- ... avoir commencé il y a deux mois\\Net finir aujourd'hui?",
#  "Mauvaise réponse!\\NDroit de réplique de l'Ontario.",
#  "Trop long! C'est plus fucké\\Nque ça, c'est l'inverse.",
#  "Le bout qui saigne a été\\Nfait avant qu'il meure.",
#  'La partie qui saigne pas\\Na été faite après.',
#  'Ça se voit à cause\\Nde la pigmentation.',
#  'Il était mort avant la chute.',
#  "Et c'est là que j'en arrive avec ça.",
#  'La coagulation sanguine\\Nde cette blessure-là',
#  'correspond à celle du taaattoo.',
#  'Les blessures de la chute\\Nsont plus récentes.',
#  'Les patterns sont pas les mêmes.',
#  "- Ça fait qu'il était mort\\Navant de tomber?",
#  "D'abord pourquoi le tatou?\\NUne signature?",
#  '- Logique. Le tatouage\\Nne correspond pas à son statut.',
#  'Quand on porte\\Nun complet Armani à 5 000$',
#  "et partenaire d'un cabinet,\\Non n'arbore pas de tatouage.",
#  '- Pourquoi pas?',
#  '- Ça fait pas très classe.',
#  '- Angelina Jolie,\\Nelle en a, des tatous.',
#  "- C'est exactement ce que je veux dire.",
#  'Mais pourquoi une fleur de lys\\Navec une balance?',
#  '- Hum, hum!\\N- Je peux te donner 1000 raisons.',
#  '- Hé!\\N- Une seule suffira.',
#  '- Hum!',
#  '- On peut aller demander\\Nà ses partners.',
#  'Merci, Jeff.\\N- Pas de trouble.',
#  "S'il y a du neuf, je t'appelle.\\N- Oh.",
#  "- Désolé, je n'ai pas compris\\Nla moitié de ce qu'il a dit.",
#  "- Fais-toi-z'en pas,\\Nmoi non plus.",
#  "Si on n'a pas la même moitié,\\Non est corrects.",
#  '- Han, han, Oh.',
#  'Parfait. Merci, Stéphane.\\NOn y va tout de suite.',
#  'Changement de plan.',
#  'On ira voir Grossbut plus tard.',
#  'Comme on le pensait,',
#  "aucun vol d'hélicoptère\\Nn'a été enregistré hier.",
#  'Mais un fermier a vu un hélico\\Npasser par-dessus son champ.',
#  "Il a pu voir qu'il appartenait\\Nà Hélicoptères Libellules,",
#  "une petite compagnie\\Nà l'aéroport de Saint-Hubert.",
#  "- Oh. Qu'est-ce qu'on fait?",
#  'On va-tu voir le fermier\\Nou bien on va à Saint-Hubert?',
#  '- Allons directement à Saint-Hubert.',
#  "- Seigneur!\\NQu'est-ce que tu fais?",
#  "Tu ne peux pas faire ça,\\Ntu n'as même pas de sirène de police.",
#  '- Baisse ta fenêtre puis\\Nfais le bruit avec ta bouche.',
#  'Come on!',
#  '- Il va falloir établir\\Nquelques règles de base entre nous.',
#  'Pas de problème.',
#  'Règle numéro un,\\Non est au Québec, je suis en charge.',
#  "Je m'occupe aussi des batailles\\Npuis des poursuites en auto.",
#  '- Il me reste donc les traversées\\Nillégales et la circulation!',
#  '- Tant que ça implique\\Npas des échelles.',
#  '- Et interdiction de fumer.',
#  "- Hé, c'est ton droit.\\N- Pourquoi t'allumes-tu?",
#  "- J'ai des droits, moi aussi.",
#  'Je suis dans la section fumeur.',
#  '- Ah!',
#  'Ouf!',
#  'Ta voiture te ressemble beaucoup.',
#  '- Merci.',
#  "- Règle numéro 12: c'est moi\\Nqui interroge les témoins.",
#  '- Si tu veux, mais en français.',
#  '- Ça dépend de la langue\\Nmaternelle du sujet.',
#  '- Non, au Québec,\\Non travaille en français.',
#  '- Parfait! Le reste du Canada\\Nest donc sous ma juridiction.',
#  'Sauf quelques régions\\Ndu Nouveau-Brunswick.',
#  '- Wô, wô, ça commence bien mal, là.\\NEn français!',
#  '- Mon Dieu... Excusez-moi, là.',
#  "Ha! Ha! J'ai tout ça ici.",
#  '- Prenez votre temps, madame.',
#  "Combien avez-vous d'hélicoptères?",
#  '- Trois. Mais il y en a un\\Nen réparation.',
#  "Ah! Je l'ai.",
#  "Non, aucun de nos hélicoptères\\Na volé à la frontière de l'Ontario",
#  'et le propriétaire est parti\\Navec des Américains',
#  'à Tremblant depuis une semaine.',
#  'Et Luc, un de nos pilotes,',
#  'a fait son dernier vol\\Nà 14 h 00, hier.',
#  'Un aller-retour Montréal.',
#  "C'est bizarre, ça.",
#  "- Qu'est-ce qui est bizarre?\\N- Hé!",
#  "- Excuse-moi, t'as raison,\\Ninterrogation, vas-y.",
#  "- Qu'est-ce qui est bizarre?",
#  '- Je veux pas mettre\\Npersonne dans le trouble,',
#  'mais Luc est sorti hier en fin\\Nde journée avec un des hélicoptères.',
#  "C'est peut-être juste\\Npour l'entretien.",
#  "C'est pour ça que\\Nc'est pas inscrit au registre.",
#  'Ha! Ha! Ha!',
#  '- Est-ce que vous avez un numéro\\Npour joindre ce monsieur...?',
#  '- Buh... Therrien!',
#  'Luc Therrien.',
#  'Normalement, à cette heure-ci,\\Nil devrait être au bar du coin.',
#  '- Merci, madame.\\N- Merci beaucoup.',
#  '- Tout le plaisir est pour moi!',
#  'Excusez-moi! Vous...',
#  'Vous auriez pas un numéro de\\Ntéléphone où je pourrais vous rejoindre',
#  "au cas où j'aurais\\Nd'autres renseignements?",
#  "- Buh... Malheureusement,\\Nj'ai pas de carte sur moi.",
#  '- Ah!\\NHa! Ha! Ha!',
#  "- C'est le 9...",
#  '- Oui...',
#  '- 1... 1...',
#  "C'est ça.",
#  '- Ah! Ha! Ha! Ha!',
#  '- Ils vont savoir\\Ncomment me rejoindre.',
#  'Juste à demander pour Martin Ward.',
#  '- Ward...',
#  'Ouh...',
#  'Je vais aller parker\\Nen arrière.',
#  'Et voilà!\\NLuc Therrien, 39 ans, divorcé.',
#  'Neuf ans pour trafic de cocaïne.',
#  'Après, plus rien.',
#  "Il est pilote d'hélicoptère\\Ndepuis 10 ans,",
#  'notamment chez\\NLibellules Express depuis 3 ans.',
#  '- Luc Therrien...',
#  'Ça me dit quelque chose, ce nom-là.',
#  "Je l'ai peut-être déjà arrêté.",
#  '- Hé oh! Hé oh! Attends.',
#  "L'interrogation, c'est moi\\Nqui s'en occupe, pas vrai?",
#  '- Pas de problème.',
#  'Tu peux même rentrer\\Ntout seul, si tu veux.',
#  'Je rentrerai séparément\\Nune couple de minutes après toi.',
#  '- Tien. Tu pourras observer\\Nmes méthodes.',
#  'Peut-être que tu apprendras\\Nquelque chose.',
#  "- C'est ça, oui.",
#  '- Laisse-moi évaluer la situation,\\Npuis rejoins-moi.',
#  "- Que c'est tu fais là?",
#  'Pas de badge là-dedans, là!',
#  "Surtout pas une badge de l'Ontario!",
#  'Tien voyons donc!',
#  "- As-tu tout ce qu'il te faut ici,\\Nmon noir?",
#  'Salut, mon beau noir!',
#  "Qu'est-ce que je peux te servir?",
#  "- Un ginger ale, straight up,\\Ns'il vous plaît.",
#  '- Ginger ale.',
#  'Un peu de glace?',
#  '- Non, merci.',
#  "Je cherche un pilote d'hélicoptère.",
#  "- Ha! Ha! Ha!\\NC'est pas ça qui manque ici!",
#  "C'est moi qui te l'offre.",
#  '- Merci. Un dénommé Therrien.',
#  'Ça vous dit quelque chose?',
#  '- Therrien...\\N- Luc Therrien?',
#  "- Ah, Luc! Tien t'es chanceux,\\Nmon beau noir,",
#  "parce qu'il est justement là.\\N- Merci.",
#  'Tabarnak!',
#  "T'es chanceux aujourd'hui, toi!\\NCrisse! Rita!",
#  'Donne-moi deux bières.',
#  '- Beau jacket.',
#  '- Merci... mon père.',
#  'Beau col roulé.',
#  "Bon, c'est une joke, là!",
#  'Rita, paie donc\\Nun autre verre à monsieur.',
#  '- Ginger ale?\\N- Ouh! Ginger ale!',
#  "Veux-tu qu'on t'appelle Nez Rouge?",
#  "- Saviez-vous que l'Association\\Ncanadienne des maladies du coeur",
#  'dit que deux boissons\\Nalcoolisées par jour',
#  'sont bénéfiques pour la santé,',
#  'mais quand on dépasse trois ou plus,\\Non se rapproche de notre tombe.',
#  "- Toi, Luc, ça doit bien faire\\N7 ans que t'es mort! Ha!",
#  "- C'est pour me calmer,\\Nquand il y en a",
#  'qui me tapent sur les nerfs.',
#  'Avez-vous essayé le yoga?',
#  '- Moi, le yoga, je connais\\Npas mal toutes les positions.',
#  '- Toi, Rita, on les connaît,\\Ntoutes tes positions!',
#  '- Un peu de respect pour la dame.',
#  "- Tu viens d'où, toi?",
#  '- Toronto.',
#  '- Ah ouais?',
#  "C'est peut-être pour ça\\Nque je t'aime pas la face?",
#  "Que c'est que tu câlices ici?",
#  '- Un sondage.',
#  "J'ai quelques questions\\Nà vous poser",
#  'au sujet de Benoît Brisset.',
#  "Nous savons qu'il...",
#  'Je repose la question.',
#  'Benoît Brisset,\\Nça vous dit quelque chose? Ça va!',
#  'Oh!',
#  '- Ah!',
#  'Bouchard!',
#  'Fais quelque chose!',
#  'Bouchard, aide-moi!',
#  "- Il y a-tu quelqu'un\\Nqui comprend l'anglais, ici,",
#  'parce que je pense que le monsieur\\Navec la face mauve,',
#  'il essaie de me dire quelque chose.',
#  '- David!',
#  "Aide-moi, s'il te plaît!",
#  '- Avec plaisir.',
#  '- Mêle-toi pas de ça, toi.',
#  '- Han!',
#  '- Ah!',
#  "- C'est correct, regarde,\\Nje m'en occupe.",
#  "- Je pense pas\\Nque c'est une bonne idée.",
#  "- On en a parlé tantôt:\\Nles batailles, je m'en occupe.",
#  'Repose-toi un petit peu,\\Nça va être correct.',
#  '- Yah! Ah!',
#  '- Merci.',
#  'Monsieur Therrien, il semblait nerveux,\\Nces derniers jours?',
#  "- Ah, pas plus que d'habitude.",
#  '- Ah!',
#  '- Oh!',
#  'Martin, aide-moi!',
#  '- Je peux avoir un peu de citron?',
#  '- Tien sûr, mon beau noir!',
#  '- Martin, niaise pas!',
#  "- Et s'il y a quoi\\Nque ce soit, ma carte.",
#  'Je suis désolé,\\Nje ne comprends pas.',
#  'Fuck you!',
#  '- Bonne langue, mauvais mots.',
#  "- Martin, aide-moi, s'il te plaît.",
#  '- Excusez.',
#  '- Lâche mon partenaire.',
#  "- Ah!\\N- Qu'est-ce que tu fais?",
#  "J'ignore si tu ne respectes\\Npas la procédure",
#  'parce que tu es ignorant,\\Ncinglé ou français.',
#  'Tu ne peux pas faire ça!',
#  '- Ha! Ha!',
#  "- C'est quoi, la procédure,\\Ndans ce temps-là?",
#  '- Hé...',
#  "C'est ta juridiction.",
#  '- Merci.',
#  '- Mon hostie de câlice\\Nde pourri sale!',
#  '- Surveille ton langage.',
#  "- Qu'est-ce qu'il a dit?",
#  "- Qu'on est des pourris sales.",
#  '- J\'avais compris ça,\\Nmais "hostie de câlice"?',
#  '- Ce sont des gros mots.',
#  'Comme "hostie de pourri",\\Nc\'est pourri pas mal.',
#  'Mais...',
#  'Hostie de câlice de pourri,',
#  "ça, ça commence à être vraiment\\Npourri, mais c'est pas si pire",
#  "parce qu'il y a déjà\\Nquelqu'un qui m'a traité",
#  "d'hostie de pourri\\Nde câlice de tabarnak.",
#  '- Ah oui, méga pourri.',
#  "- Attends que je sorte d'ici,\\Ntu vas trouver ça moins drôle.",
#  "- Chut! Chut! J'ai pas fini.",
#  'Tu peux le conjuguer aussi.\\N- Comme un verbe?',
#  "- M'as t'en câlicer une!\\N- C'est beau, Luc!",
#  '- C\'est un bel exemple,\\N"m\'as t\'en câlicer une".',
#  'Tu peux le faire\\Nau masculin aussi.',
#  'Comme "je vais t\'en crisser un".',
#  "- J'ai compris.\\NToi, mon tabarnak, là!",
#  "- Ah, merci!\\NTu vois, j'allais l'oublier, celui-là.",
#  "Tu peux l'utiliser comme\\Nun nom, il a raison,",
#  'comme "je vais t\'en donner\\Nun tabarnak".',
#  "C'est un nom propre.",
#  "Ah, c'est vrai,\\Non a des expressions, aussi!",
#  'Comme "je m\'en câlice".\\N- Ah!',
#  "- C'est assez.\\NTu veux pas qu'il porte plainte.",
#  "- Je m'en câlice.\\N- Oh!",
#  '- Voyons!',
#  "Voyons! Que c'est...\\N- Ah!",
#  "- Voyons!\\NQue c'est qui se passe?",
#  'Lulu!\\N- Quoi?',
#  '- Ta botte, elle bloque le coffre.',
#  '- Ah, excusez. Ah...',
#  "- J'espère que tu ne parles pas\\Ncomme ça devant les enfants.",
#  '- Ciboire de tabarnak, Gabrielle!',
#  "- J'ai ma réponse.",
#  'Cette place est réservée\\Naux handicapés.',
#  'Tu ne peux pas te garer ici.',
#  '- Tien oui, je peux, je suis avec toi.',
#  "- Donne-moi les clés de l'auto.",
#  "- Non.\\N- C'est ridicule, David!",
#  "On peut pas laisser un suspect\\Ndans le coffre d'une auto",
#  'parce que ta fille\\Na un spectacle de ballet!',
#  '- Pourquoi?',
#  'Tabarnak!',
#  'Bravo, mesdemoiselles!',
#  'On les applaudit chaleureusement.',
#  "- Ça paraît que t'as pas d'enfant!",
#  "- J'ai un fils que j'élève seul.",
#  '- Le trou de cul qui est dans mon char\\Nest moins important que nos enfants!',
#  "- Il y a une raison\\Nà l'existence des règlements.",
#  "- Je veux plus en entendre\\Nparler, c'est un ordre.",
#  '- Un ordre?\\N- Ouais.',
#  '- Hé!',
#  '- Excusez, excusez-moi.',
#  'Excusez-moi...',
#  'Assis-toi!',
#  "- J'ai-tu manqué Gabrielle?",
#  'Tien non!',
#  "- C'est Martin, il vient de Toronto,\\Nil travaille pour moi sur un dossier.",
#  '- Mes sympathies.\\N- Enchanté de vous rencontrer.',
#  "- Hum, hum!\\N- C'est mon ex, Suzie.",
#  "- Ah. Mes sympathies.\\N- Qu'est-ce que tu veux dire?",
#  '- HUM! HUM!',
#  'Bon, merci.',
#  'Maintenant que nous avons\\Nvotre attention,',
#  'nous allons pouvoir vous présenter',
#  'notre groupe le plus avancé.',
#  'Elles sont très nerveuses,\\Nalors on les encourage très fort.',
#  "- C'est eux autres!",
#  "C'Est EUX AUTRES!",
#  'Gabrielle! Ouh, ouh!',
#  "Let's go, les filles!\\NVous êtes capables!",
#  'Mathieu aussi!',
#  '- Musique.',
#  '- Calme-toi, ça va bien aller.',
#  "Levez! C'est ça!",
#  "Relevez! Ouais!\\NC'est bien parti.",
#  'Ouais.',
#  'Arabesque...',
#  'Entrechat! Yes! Ouh!\\N- Chut!',
#  "- Hé, c'est pas facile, ça!",
#  'Il est obligé de mettre ses mains là?\\N- Hé, calme-toi!',
#  "- C'est elle, la mienne!\\NEn avant dans le milieu.",
#  '- Je sais.',
#  "- Oui! C'est beau.",
#  'Ça va être la fin.',
#  'Entrechat, entrechat...',
#  "C'est ça!",
#  'YES!',
#  'Yes! All right!',
#  "C'est beau, ma cocotte!\\N- Bravo!",
#  'Mathieu, you rock!',
#  "Elle, en avant,\\Nc'est la mienne, ça!",
#  "Aujourd'hui, t'étais géniale!",
#  'Puis tes pas de basque, là... wow!',
#  '- Ha! Ha! Ha!',
#  "- T'as volé le show.",
#  '- On doit vraiment y aller.',
#  "- Oh.\\N- Tu t'en vas?",
#  '- Ouais. Je vais être là\\Npour le souper, promis.',
#  'On va célébrer ton triomphe!',
#  '- Oui!\\N- Bisou.',
#  '- Ton ami, il vient, lui aussi?',
#  '- Hein? Quel ami?',
#  '- Ton employé.',
#  'Martin, vous allez\\Nvenir souper avec nous?',
#  '- Bah, oui, avec plaisir.',
#  '- Fantastic!',
#  'Alors, on se voit plus tard?\\N- Oui, plus tard.',
#  '- "Fantastic"?',
#  '- Quoi?',
#  "- C'est quoi, là, tout à coup,\\Nt'es rendue bilingue?",
#  "- Hé! On n'est pas tous\\Nparfaits comme toi!",
#  '- On se voit tantôt, Oh?',
#  'Martin, tu veux pas venir\\Npour le souper,',
#  "tu veux aller te reposer à l'hôtel,\\Nje comprends ça.",
#  '- Au contraire, ça me fait plaisir.',
#  "- Tu serais vraiment\\Nmieux d'aller te reposer.",
#  "- On m'avait dit que\\Nles Québécois étaient chaleureux,",
#  "mais je pensais pas\\Nque c'était autant que ça.",
#  'Tiens!',
#  "Rita, la serveuse,\\Nm'a laissé un message.",
#  '- Pourquoi tu vas\\Npas souper avec elle?',
#  'Tu devrais aller souper avec,',
#  'parce que tu sais\\Nque les Québécoises...',
#  'Hé, mon char!',
#  'Mon char!',
#  "- Je t'avais dit!\\N- HÉ!",
#  '- Police! Arrêtez-vous!',
#  '- HÉ! MON CHAR!',
#  '- POLICE!',
#  'FREEZE!',
#  'Tu vois, même en anglais,\\Nça marche.',
#  "- Ouais, c'est ça.",
#  '- On aurait pu avoir\\Nde gros problèmes.',
#  "- T'es tellement négatif...",
#  '- Le suspect!',
#  '- Mon char!',
#  '- Comment allons-nous expliquer ça?',
#  "- Pour l'instant,\\Non n'expliquera rien.",
#  '- Quoi?\\NEs-tu fou?',
#  'Un suspect est mort dans la voiture.\\NIl faut faire un rapport.',
#  "- C'est toi qui es fou!",
#  'Comment ton boss va réagir',
#  'quand il va se rendre\\Ncompte de ta négligence?',
#  '- MA NÉGLIGENCE?',
#  "Je t'ai dit que je pouvais\\Nle ramener seul au quartier général,",
#  'mais tu voulais te pavaner\\Navec lui devant tes copains.',
#  '- Si tu y tenais tant\\Nà tes procédures,',
#  "t'avais rien qu'à rester\\Ndehors puis à le surveiller",
#  'au lieu de venir te téter un souper,',
#  'puis flirter mon ex-femme\\Ndevant ma fille!',
#  "- C'est ça!\\NTu es complètement fou.",
#  "Je m'en vais écrire un rapport\\Ndétaillant toute la situation.",
#  'Tu ne me traîneras pas\\Ndans la merde avec toi.',
#  "- Trop tard, t'es dedans\\Npar-dessus la tête!",
#  'Si tu veux pas perdre ta job,',
#  'il faut fermer notre gueule puis\\Ntrouver le malade qui a fait ça.',
#  "C'est la seule solution.",
#  '- Shit de merde de shit\\Nde fuck de tabarnak!',
#  "- 24 heures,\\Nsi dans 24 heures on n'a rien,",
#  "je vais tout expliquer\\Nce qui s'est passé.",
#  '- Pas une de plus.',
#  "- En tout cas, l'enquête avance.",
#  "Tien, astheure,\\Non sait que c'était pas lui.",
#  '- Ah...',
#  "- Tien quoi, c'est vrai!",
#  'Café?\\N- Merci.',
#  "C'était délicieux!\\N- Merci.",
#  "- J'ai bien aimé votre saumon\\Nfaçon bistrot français.",
#  "Moi, je le prépare à l'américaine.",
#  '- Vous cuisinez?\\N- Certainement!',
#  '- Ah! À part son pain doré,',
#  'David a jamais été\\Ntrès utile dans une cuisine!',
#  '- Mais il y a une autre pièce\\Noù tu me trouvais très utile.',
#  '- Ha!\\N- Ha...',
#  'Quand même,',
#  "c'est rare de voir des divorcés\\Nqui vivent ensemble,",
#  'dans la même maison,\\Ncomme une famille normale.',
#  '- Pff! Normale!',
#  "- T'es divorcé, toi aussi?\\N- Ha! Ha! Ha!",
#  "- Gabrielle!\\N- Ce n'est pas grave.",
#  'Oui, Gabrielle,\\Nje suis divorcé aussi.',
#  "- Qu'est-ce qui s'est passé?",
#  "Tien quoi? Ça m'intéresse.",
#  '- Ma femme était attachée de presse',
#  'pour le Gouverneur général\\Ndu Canada.',
#  "Ellel'accompagnait\\Ndans tous ses voyages.",
#  'Un jour, elle était à Londres\\Npour une visite à la famille royale.',
#  "Ellem'a appelé\\Nau travail pour me dire",
#  "qu'elle ne reviendrait pas",
#  "et qu'elle voulait se fiancer\\Nà un semi-prince",
#  'de je ne sais trop quoi.',
#  "Je ne l'ai jamais revue.",
#  '- Tu niaises, là?\\NNon.',
#  "- Ç'a dû être un choc?",
#  '- Jonathan avait 8 ans.',
#  'Il la voit deux fois par année.',
#  "Pour Noël et deux semaines l'été.",
#  "- Mais c'est quoi, un semi-prince?",
#  "- C'est un grand riche\\Navec des jambes de grenouille.",
#  "- Bon, bien...\\NÇa va être l'heure du dodo, hein?",
#  "- P'pa, il est juste 7 h 30!",
#  '- Pas toi, ma chouette,\\Nje parle à Martin.',
#  'Quoi? Il est tard, il doit être fatigué.\\NOn a une grosse journée demain.',
#  '- Tu as raison.\\NIl faut aller chez Therrien.',
#  'Je devrais partir.',
#  '- Pourquoi vous dormez pas ici?\\NTien oui, chez David, en haut!',
#  'Comme ça, vous partez tôt\\Ndemain matin, pas de problème!',
#  "- Voyons, Suzie, chez nous,\\Nc'est à l'envers, là!",
#  "- On s'en fout!\\N- Je peux lui prêter ma chambre.",
#  'Je vais aller dormir en haut.\\N- Voilà!',
#  "- On va s'en reparler\\Nde ton nombril, toi!",
#  '- La serveuse ne répond pas\\Nà son cellulaire.',
#  "- Que c'est qu'ils font\\Navec leur hostie de paperasse?",
#  '- Prenais-tu du Ritalin\\Nquand tu étais jeune?',
#  '- Hein?',
#  '- Pense à autre chose.',
#  'Ta fille est adorable.',
#  "- C'est vrai.\\NOn est bien chanceux.",
#  "C'est une enfant remarquable.",
#  '- Tu avais raison.',
#  'Les Québécoises sont...',
#  'spéciales.',
#  '- Tu parles-tu de Suzie, là?\\N- Elle est vraiment superbe.',
#  'Ellea les pieds sur terre.',
#  '- Tu cherches quoi, là?\\N- What?',
#  '- Sais-tu quoi?',
#  'Ça marche pas, ton truc.',
#  '- Bouchard, on attend le mandat.',
#  "- Je m'en câlice!\\N- Bouchard! Come on!",
#  "- Je m'en câlice!\\NJe m'en câlice!",
#  '- Bravo!',
#  'Maintenant, on ne peut plus\\Nse servir des preuves.',
#  'Idiot!',
#  '- Shit...',
#  'Martin!',
#  'Viens voir ça!',
#  '- Pas sans mandat.',
#  "- Ah, come on!\\NJ'ai déjà pété la porte, anyway!",
#  "Je pensais avoir vu\\Nquelqu'un en détresse!",
#  '- Ah... Et merde!',
#  '- AH!\\NHa! Ha! Ha!',
#  'Ha! Ha! Ha!',
#  '- Peux-tu essayer de ne plus\\Ntoucher aux preuves?',
#  '- Juste te voir la face,\\Nça valait la peine.',
#  'Hostie de malade.',
#  "Ha... je comprends pourquoi\\Nj'avais l'impression",
#  'de le connaître, le Therrien.',
#  'Je me rappelle, là.',
#  "Il a été repêché par Québec,\\Npuis à la moitié de l'année,",
#  'il a été suspendu\\Npour une affaire de dope.',
#  '- Ça explique le tatouage.',
#  "- Tu penses qu'il a fait ça\\Nà cause du hockey",
#  'ou à cause de la dope?',
#  '- Les deux, peut-être.',
#  "- C'est lui, Grossbut.",
#  '- Hum...\\N- Tu le connais?',
#  "C'est le gros sale qui a vendu\\NQuébec au Colorado.",
#  "- L'année suivante,\\Nils ont gagné la Coupe.",
#  "Je vais te laisser finir\\Nton petit projet d'art plastique.",
#  'Je vais aller voir en bas.\\N- Oh.',
#  "J'ai compris que c'était toujours...",
#  'Bye, au revoir...',
#  '- David!',
#  'Grossbut est ici!',
#  '- Martin! Viens voir ça!',
#  'Jackpot!',
#  'Que fais-tu encore ici',
#  "Va-t'en dans ton pays...",
#  '- Ici détective Martin Ward.',
#  'On a trouvé un cadavre.',
#  'Au revoir',
#  'Oh je...',
#  'Mais quand tu seras loin',
#  '- Shit!',
#  'David!',
#  "Qu'est-ce qu'il a encore fait?",
#  '- Ça va bien!',
#  "Martin! Que c'est qu'il fait, hostie?\\NIl prend des photos du feu?",
#  "Hostie de câlice de tabarnak\\Nde crisse d'hostie!",
#  "Crisse de vierge d'hostie\\Nde tabarnak de câlice!",
#  'Ah!',
#  "Pourquoi c'est tout le temps\\Nmoi qui est dans la marde?",
#  'Ouch!',
#  'Shit!',
#  "Je sors d'ici,\\Nje m'achète une cravate.",
#  '- David!',
#  'David!',
#  '- Ah!',
#  'Ah... Ah... Ah...',
#  "- Qu'est-ce que c'est que cette odeur?",
#  '- AAAAAAAAAAH!',
#  '- Ouf...',
#  'AAAH!',
#  'Martin!',
#  '- Ici! Sors Grossbut!',
#  '- Laisse faire.',
#  "- Sors-le avant!\\N- Viens-t'en!",
#  'Assieds-toi ici!',
#  'Ça va?',
#  "Donne-moi-z'en un peu.\\N- C'est mon inhalateur!",
#  "Voyons, qu'est-ce que j'ai?",
#  'Je me sens bizarre.',
#  '- Moi aussi.',
#  "Câlice d'hostie de sacrament",
#  "de ciboire de crisse d'hostie",
#  'de viarge de tabarnak!',
#  '- Ha! Ha! Ha!',
#  "- Ce n'est pas un compliment.\\N- Calvaire, David!",
#  "T'es rentré avant même\\Nqu'on t'envoie le mandat!",
#  'Tu mets un suspect\\Ndans ta valise,',
#  'ce qui reste,\\Non le met dans un Ziploc!',
#  'Trouves-tu ça normal, toi?',
#  '- Tien là, il faut pas capoter,',
#  'il avait un dossier\\Nplus long que ton bras.',
#  "C'était pas le frère André.\\N- Frère André!",
#  '- On a été obligés\\Nde le ramasser à la spatule!',
#  "Vous avez fait sauter l'édifice, puis\\Nvous avez oublié la victime dedans!",
#  '- Il y a mon char aussi.',
#  '- INTERROMPS-MOI PAS\\NQUAND JE PARLE, Oh?',
#  '- Ha! Ha! Ha!\\N- En effet, chef,',
#  "c'est de ma faute.",
#  "J'ai cru voir",
#  "quelqu'un à l'intérieur en détresse.",
#  "Il y avait quelqu'un,",
#  'mais pas celui que je pensais.',
#  'Il était en détresse,',
#  "mais pas aujourd'hui.",
#  "C'est à peu près ça, non?",
#  '- Captain MacDuff, ligne 3.',
#  '- Captain MacDuff...\\NAvez-vous eu mon message',
#  'sur les agissements\\Nde votre policier fou?',
#  '- Oui.\\N- Il a incendié une maison.',
#  'Il a fait exploser le témoin!',
#  "- C'est vrai, Martin?",
#  '- Well... Buh...',
#  'Compte tenu\\Nde la situation, monsieur,',
#  'on pourrait qualifier\\Ncette affaire de...',
#  "C'était quoi, la question?",
#  '- Le témoin!',
#  "- Non, j'ai un alibi.",
#  "J'assistais au spectacle de ballet\\Nde la fille de David.",
#  '- Quoi?',
#  '- Martin, reviens immédiatement.',
#  "Tu n'as plus rien à faire là-bas.",
#  '- Moi, de toute façon,\\Nje vais être bien mieux',
#  "si j'ai pas un touriste à traîner.",
#  '- Monsieur, laissez-moi arranger ça.',
#  "J'ai passé la moitié du temps\\Nà surveiller un Rambo sur stéroïdes.",
#  'Je peux arranger ça.',
#  '- Vos gueules! VOS GUEULES!\\NVOS GUEULES!!!',
#  '- Ayoye...',
#  '- And you!\\NMon espèce de vache folle!',
#  'À partir de tout de suite...\\NRenvoyé! Renvoyé!',
#  "Tu retournes en Ontario,\\Nun point, c'est tout.",
#  'Retourne chez vous puis reste là!',
#  "Hein?\\NC'est fini, là, fini!",
#  'FINI!\\N- Ha! Ha!',
#  '- Puis toi, là! Toi!',
#  "Puis toi, tout ce que j'te demande...",
#  "... is you take la tête carrée\\Njusqu'à l'aéroport!",
#  "C'est ta fucking day d'ouvrage,\\Naujourd'hui!",
#  '- Roger!',
#  '- DEHORS!\\NEnvoye, dehors!',
#  "- C'est par là.\\N- Pff!",
#  "- Sors d'ici! Sors d'ici!",
#  'Sors! SORS!',
#  "- Come on!\\NJ'ai les munchies, là!",
#  "- Tout compte fait,\\Nj'aurai beaucoup appris.",
#  'Mais les deux victimes\\Nsont québécoises,',
#  'le suspect mort, québécois...',
#  "Pour le meurtrier, je parierais\\Nqu'il est québécois aussi, alors...",
#  'Bye-bye!\\NDis à Suzie que je vais lui écrire.',
#  "- C'est quoi, ton affaire avec Suzie?",
#  "Tu l'as vue rien qu'une fois!",
#  '- Les Québécois sont tous pareils.',
#  "Un cinglé est obsédé par une équipe\\Nde hockey qui n'existe plus...",
#  'Et toi avec Suzie... ?',
#  '"Je me souviens".',
#  'Vous vivez dans le passé,\\Nrevenez-en!',
#  '- Au moins, nous autres,\\Non est encore vivants!',
#  'Vous autres, vous avez\\Njuste votre reine',
#  ...]

# %%
bcbc_gs = pd.read_excel('BCBC_GS_annotator1.xlsx')

# %% [markdown]
#     eng frn
# eng
# frn

# %%
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'] != 'French/English']
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'] != "None"]
bcbc_gs = bcbc_gs[bcbc_gs['Listened Language'].notnull()]
bcbc_gs['Listened Language'].value_counts()
# Out:
# French     7650
# English    5803
# Name: Listened Language, dtype: int64

# %%
def prob_matrix(tokens, langs):
    """
    tokens: a pandas series containing all the tokens
    """
    
    switches = {lang: {}  for lang in langs}
    counts = Counter(zip(tokens, tokens[1:]))

    for (x, y), c in counts.items():
        switches[x][y] = c / float(len(tokens) - 1)
        
    return switches

# %%
prob = prob_matrix(bcbc_gs['Listened Language'], \
                             set(bcbc_gs['Listened Language']))
prob
# Out:
# {'French': {'French': 0.5489146595301814, 'English': 0.01977401129943503},
#  'English': {'French': 0.019699672911091287, 'English': 0.4116116562592923}}
